# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pprint

# %%
def get_throughput_bytes_per_hour(df):
    # Throughput B / hr
    sim_time_hours = float(df.loc[df['name'] == 'simulated time'].value.iloc[0]) / 60 / 60
    bytes_per_data_packet = int(df.loc[df['name'] == 'dataPacketLenBits'].value.iloc[0]) / 8
    num_data_packets = int(df.loc[df['name'] == 'numDataPacketsReceived'].value.iloc[0])

    return (num_data_packets * bytes_per_data_packet) / sim_time_hours

def get_jfi(df):
    # Jain's Fairness Index
    num_nodes = int(df.loc[df['name'] == 'nrOfNodes'].value.iloc[0])
    denominator = num_nodes * df[df['name'].str.startswith('numDataPacketsReceivedByNodeId', na=False)].value.astype(int).pow(2).sum()
    numerator =  df[df['name'].str.startswith('numDataPacketsReceivedByNodeId', na=False)].value.astype(int).sum() ** 2.0
    jfi = numerator / denominator if denominator != 0 else 0
    return jfi

# %%
import os

results_path = "/home/jason/Applications/omnetpp-6.0.1/samples/florasat/simulations/satellitewired/results"
sca_files = [f for f in os.listdir(results_path) if f.endswith(".sca")]

sim_data = []

for file_name in sca_files:
#     os.system(f"opp_scavetool x {os.path.join(results_path, file_name)} -o {file_name}.csv")

    df = pd.read_csv(f"{file_name}.csv", dtype="unicode")
    
    parts = file_name.split('-')[1].split(",")
    name = parts[1]
    params = [param.split("=")[1] for param in parts[2:6]]
    run_data = [parts[1], *params, get_throughput_bytes_per_hour(df), get_jfi(df)]
    
    sim_data.append(run_data)

sim_data.sort(key=lambda run_data: (int(run_data[4]), float(run_data[5])))

header = [
    "Protocol",
    "wrx",
    "alpha",
    "multiplier",
    "nrOfNodes",
    "Throughput [bytes / hour]",
    "Jain Fairness Index"
]
sim_data.insert(0, header)    

display(pd.DataFrame(sim_data))
df = None
# Out:
#                  0    1      2           3          4
# 0         Protocol  wrx  alpha  multiplier  nrOfNodes  \
# 1   RESSIoTNodeMac    7    0.1         0.1         10
# 2   RESSIoTNodeMac    9  0.125         0.2         10
# 3   RESSIoTNodeMac    7   0.15         0.2         10
# 4   RESSIoTNodeMac    9    0.2         0.2         10
# 5   RESSIoTNodeMac    5   0.15         0.1         10
# 6   RESSIoTNodeMac    9    0.1         0.1         10
# 7   RESSIoTNodeMac    7    0.2         0.2         10
# 8   RESSIoTNodeMac    5  0.175         0.1         10
# 9   RESSIoTNodeMac    9   0.15         0.1         10
# 10  RESSIoTNodeMac    7  0.125         0.1         10
# 11  RESSIoTNodeMac    9  0.125         0.1         10
# 12  RESSIoTNodeMac    9  0.175         0.2         10
# 13  RESSIoTNodeMac    9    0.2         0.1         10
# 14  RESSIoTNodeMac    9    0.1         0.2         10
# 15  RESSIoTNodeMac    7    0.1         0.2         10
# 16  RESSIoTNodeMac    7  0.125         0.2         10
# 17  RESSIoTNodeMac    5    0.1         0.1         10
# 18  RESSIoTNodeMac    9  0.175         0.1         10
# 19  RESSIoTNodeMac    7    0.2         0.1         10
# 20  RESSIoTNodeMac    7  0.175         0.2         10
# 21  RESSIoTNodeMac    7   0.15         0.1         10
# 22  RESSIoTNodeMac    5  0.125         0.2         10
# 23  RESSIoTNodeMac    5    0.2         0.1         10
# 24  RESSIoTNodeMac    5    0.1         0.2         10
# 25  RESSIoTNodeMac    5   0.15         0.2         10
# 26  RESSIoTNodeMac    9   0.15         0.2         10
# 27  RESSIoTNodeMac    7  0.175         0.1         10
# 28  RESSIoTNodeMac    5  0.125         0.1         10
# 29  RESSIoTNodeMac    5    0.2         0.2         10
# 30  RESSIoTNodeMac    5  0.175         0.2         10
# 31  RESSIoTNodeMac    5    0.1         0.1         50
# 32  RESSIoTNodeMac    7    0.1         0.1         50
# 33  RESSIoTNodeMac    5    0.1         0.2         50
# 34  RESSIoTNodeMac    7    0.1         0.2         50
# 35  RESSIoTNodeMac    9    0.1         0.2         50
# 36  RESSIoTNodeMac    9    0.1         0.1         50
# 37  RESSIoTNodeMac    9  0.125         0.1         50
# 38  RESSIoTNodeMac    5  0.125         0.2         50
# 39  RESSIoTNodeMac    5  0.125         0.1         50
# 40  RESSIoTNodeMac    7  0.125         0.2         50
# 41  RESSIoTNodeMac    7  0.125         0.1         50
# 42  RESSIoTNodeMac    9  0.125         0.2         50
# 43  RESSIoTNodeMac    7   0.15         0.2         50
# 44  RESSIoTNodeMac    7   0.15         0.1         50
# 45  RESSIoTNodeMac    5   0.15         0.2         50
# 46  RESSIoTNodeMac    9   0.15         0.2         50
# 47  RESSIoTNodeMac    9   0.15         0.1         50
# 48  RESSIoTNodeMac    7  0.175         0.2         50
# 49  RESSIoTNodeMac    9  0.175         0.1         50
# 50  RESSIoTNodeMac    5  0.175         0.1         50
# 51  RESSIoTNodeMac    5   0.15         0.1         50
# 52  RESSIoTNodeMac    7  0.175         0.1         50
# 53  RESSIoTNodeMac    9    0.2         0.1         50
# 54  RESSIoTNodeMac    9  0.175         0.2         50
# 55  RESSIoTNodeMac    7    0.2         0.2         50
# 56  RESSIoTNodeMac    5  0.175         0.2         50
# 57  RESSIoTNodeMac    7    0.2         0.1         50
# 58  RESSIoTNodeMac    9    0.2         0.2         50
# 59  RESSIoTNodeMac    5    0.2         0.2         50
# 60  RESSIoTNodeMac    5    0.2         0.1         50
# 61  RESSIoTNodeMac    5    0.1         0.1        100
# 62  RESSIoTNodeMac    5    0.1         0.2        100
# 63  RESSIoTNodeMac    7  0.125         0.1        100
# 64  RESSIoTNodeMac    7    0.1         0.2        100
# 65  RESSIoTNodeMac    9    0.1         0.2        100
# 66  RESSIoTNodeMac    7    0.1         0.1        100
# 67  RESSIoTNodeMac    9    0.1         0.1        100
# 68  RESSIoTNodeMac    9  0.125         0.1        100
# 69  RESSIoTNodeMac    7  0.125         0.2        100
# 70  RESSIoTNodeMac    9  0.125         0.2        100
# 71  RESSIoTNodeMac    5  0.125         0.2        100
# 72  RESSIoTNodeMac    5  0.125         0.1        100
# 73  RESSIoTNodeMac    9   0.15         0.1        100
# 74  RESSIoTNodeMac    7   0.15         0.1        100
# 75  RESSIoTNodeMac    7   0.15         0.2        100
# 76  RESSIoTNodeMac    5   0.15         0.1        100
# 77  RESSIoTNodeMac    7  0.175         0.2        100
# 78  RESSIoTNodeMac    9   0.15         0.2        100
# 79  RESSIoTNodeMac    5   0.15         0.2        100
# 80  RESSIoTNodeMac    5  0.175         0.1        100
# 81  RESSIoTNodeMac    7  0.175         0.1        100
# 82  RESSIoTNodeMac    5  0.175         0.2        100
# 83  RESSIoTNodeMac    9  0.175         0.1        100
# 84  RESSIoTNodeMac    9  0.175         0.2        100
# 85  RESSIoTNodeMac    5    0.2         0.2        100
# 86  RESSIoTNodeMac    5    0.2         0.1        100
# 87  RESSIoTNodeMac    7    0.2         0.1        100
# 88  RESSIoTNodeMac    9    0.2         0.1        100
# 89  RESSIoTNodeMac    7    0.2         0.2        100
# 90  RESSIoTNodeMac    9    0.2         0.2        100
#
#                             5                    6
# 0   Throughput [bytes / hour]  Jain Fairness Index
# 1                     31185.0             0.978964
# 2                     33453.0             0.953699
# 3                     33453.0             0.958953
# 4                     35154.0             0.965829
# 5                     35154.0             0.881651
# 6                     35721.0             0.920882
# 7                     35721.0             0.938298
# 8                     37989.0             0.977996
# 9                     37989.0             0.896008
# 10                    37989.0             0.949049
# 11                    37989.0             0.885404
# 12                    37989.0             0.899599
# 13                    38556.0             0.896124
# 14                    38556.0             0.899611
# 15                    38556.0             0.943673
# 16                    40257.0             0.938734
# 17                    40257.0             0.892212
# 18                    40257.0             0.898574
# 19                    40824.0             0.919149
# 20                    40824.0             0.906294
# 21                    40824.0             0.906294
# 22                    40824.0              0.86113
# 23                    41391.0             0.858132
# 24                    41391.0             0.872177
# 25                    41391.0             0.886689
# 26                    43092.0             0.896894
# 27                    43659.0              0.87837
# 28                    43659.0             0.913559
# 29                    44226.0             0.884302
# 30                    47061.0             0.914874
# 31                    36288.0             0.630154
# 32                    42525.0             0.608108
# 33                    44793.0             0.682077
# 34                    46494.0             0.686122
# 35                    48762.0             0.711154
# 36                    52731.0             0.598547
# 37                    52731.0             0.683715
# 38                    54999.0             0.737961
# 39                    54999.0              0.66968
# 40                    56700.0             0.746269
# 41                    62937.0             0.706074
# 42                    62937.0             0.767664
# 43                    62937.0             0.682604
# 44                    63504.0             0.663704
# 45                    64638.0             0.624808
# 46                    67473.0             0.793333
# 47                    67473.0             0.747282
# 48                    68607.0             0.760571
# 49                    69174.0             0.722524
# 50                    71442.0             0.774439
# 51                    71442.0             0.752417
# 52                    72576.0             0.721762
# 53                    74277.0             0.722568
# 54                    74277.0             0.751028
# 55                    76545.0             0.808204
# 56                    77112.0             0.833153
# 57                    77112.0             0.736892
# 58                    77112.0             0.797241
# 59                    77679.0             0.832328
# 60                    82782.0                 0.73
# 61                    40824.0             0.375652
# 62                    42525.0             0.442913
# 63                    48195.0             0.472222
# 64                    48762.0             0.440238
# 65                    51030.0                 0.45
# 66                    51030.0             0.455056
# 67                    53865.0              0.50419
# 68                    54999.0             0.514153
# 69                    57267.0             0.517817
# 70                    57267.0             0.528549
# 71                    58968.0             0.487207
# 72                    59535.0             0.477273
# 73                    59535.0             0.481441
# 74                    60102.0             0.617363
# 75                    65205.0             0.567597
# 76                    67473.0             0.607768
# 77                    69174.0             0.576899
# 78                    69741.0             0.570906
# 79                    69741.0             0.579655
# 80                    72576.0                 0.64
# 81                    73143.0             0.564102
# 82                    73710.0             0.555921
# 83                    74844.0             0.584698
# 84                    74844.0             0.584698
# 85                    75411.0             0.591605
# 86                    75411.0             0.576189
# 87                    80514.0             0.589591
# 88                    82215.0             0.635196
# 89                    83916.0             0.601758
# 90                    85050.0             0.611413
