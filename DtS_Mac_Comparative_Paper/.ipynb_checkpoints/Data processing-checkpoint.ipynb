# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pprint

# %%
import os

results_path = "/home/jason/Applications/omnetpp-6.0.1/samples/florasat/simulations/dtsiot/results"
data_dir = "data"

rebuild_csv = False
if rebuild_csv:
    sca_files = [f for f in os.listdir(results_path) if f.endswith(".sca")]
    # vec_files = [f for f in os.listdir(results_path) if f.endswith(".vec")]

    for file_name in sca_files:
        print(file_name)
        os.system(f"opp_scavetool x {os.path.join(results_path, file_name)} -o {os.path.join(data_dir, file_name)}.csv")


sca_files = [f for f in os.listdir(data_dir) if ".sca" in f]
# vec_files = [f for f in os.listdir(data_dir) if ".vec" in f]

dfs = {
    "RESS-IoT": {
        "SCA": {},
        "VEC": {},
    },
    "DQ": {
        "SCA": {},
        "VEC": {},
    },
}

for file_name in sca_files:
    print(file_name)
    df = pd.read_csv(f"{os.path.join(data_dir, file_name)}", dtype=str)
    
    if ".sca" in file_name:
        numNodes = int(df.loc[df['name'] == 'nrOfNodes'].value.iloc[0])
        file_type = "SCA"
    elif ".vec" in file_name:
        numNodes = int(df.loc[df['attrname'] == "**.nrOfNodes"].attrvalue.iloc[0])
        file_type = "VEC"
    
    if "RESS-IoT" in file_name:
        protocol = "RESS-IoT"
    elif "DQ" in file_name:
        protocol = "DQ"
    
    try:
        dfs[protocol][file_type][numNodes].append(df)
    except KeyError:
        dfs[protocol][file_type][numNodes] = [df]

for protocol in dfs:
    node_counts = list(dfs[protocol]["SCA"].keys())
    node_counts.sort()
    
    dfs[protocol]["SCA"] = {node_count: dfs[protocol]["SCA"][node_count] for node_count in node_counts}
    # dfs[protocol]["VEC"] = {node_count: dfs[protocol]["VEC"][node_count] for node_count in node_counts}

pd.set_option('display.max_rows', None)   

df = None
# Out:
# DQ-N=100-#2.sca.csv
# RESS-IoT-N=500-#2.sca.csv
# RESS-IoT-N=10-#17.sca.csv
# DQExp-N=10-#0.sca.csv
# DQ-N=100-#13.sca.csv
# DQ-N=500-#13.sca.csv
# DQ-N=2000-#9.sca.csv
# RESS-IoT-N=5000-#8.sca.csv
# RESS-IoT-N=500-#0.sca.csv
# DQ-N=1000-#3.sca.csv
# RESS-IoT-N=2000-#17.sca.csv
# RESS-IoT-N=500-#6.sca.csv
# DQ-N=5000-#9.sca.csv
# DQ-N=3000-#6.sca.csv
# RESS-IoT-N=4000-#15.sca.csv
# RESS-IoT-N=3000-#6.sca.csv
# DQ-N=100-#7.sca.csv
# RESS-IoT-N=3000-#5.sca.csv
# DQ-N=500-#20.sca.csv
# DQ-N=5000-#16.sca.csv
# RESS-IoT-N=100-#15.sca.csv
# DQ-N=1000-#0.sca.csv
# RESS-IoT-N=4000-#9.sca.csv
# DQ-N=5000-#0.sca.csv
# RESS-IoT-N=5000-#13.sca.csv
# RESS-IoT-N=4000-#4.sca.csv
# RESS-IoT-N=500-#1.sca.csv
# RESS-IoT-N=100-#8.sca.csv
# DQ-N=4000-#0.sca.csv
# DQ-N=4000-#10.sca.csv
# RESS-IoT-N=500-#19.sca.csv
# DQ-N=1000-#6.sca.csv
# RESS-IoT-N=1000-#7.sca.csv
# DQ-N=100-#1.sca.csv
# RESS-IoT-N=3000-#15.sca.csv
# DQ-N=100-#3.sca.csv
# RESS-IoT-N=4000-#12.sca.csv
# RESS-IoT-N=4000-#0.sca.csv
# RESS-IoT-N=500-#4.sca.csv
# DQ-N=2000-#4.sca.csv
# DQ-N=3000-#5.sca.csv
# DQ-N=4000-#11.sca.csv
# RESS-IoT-N=1000-#9.sca.csv
# RESS-IoT-N=500-#10.sca.csv
# DQ-N=100-#14.sca.csv
# RESS-IoT-N=5000-#3.sca.csv
# RESS-IoT-N=10-#4.sca.csv
# DQ-N=5000-#10.sca.csv
# RESS-IoT-N=5000-#7.sca.csv
# DQ-N=4000-#1.sca.csv
# DQ-N=3000-#14.sca.csv
# RESS-IoT-N=3000-#0.sca.csv
# DQExp-N=2000-#0.sca.csv
# RESS-IoT-N=4000-#17.sca.csv
# DQExp-N=4000-#0.sca.csv
# DQ-N=2000-#12.sca.csv
# DQ-N=1000-#16.sca.csv
# DQ-N=1000-#15.sca.csv
# DQ-N=1000-#19.sca.csv
# RESS-IoT-N=100-#2.sca.csv
# DQ-N=5000-#8.sca.csv
# DQ-N=3000-#10.sca.csv
# DQ-N=100-#0.sca.csv
# DQ-N=2000-#16.sca.csv
# DQ-N=100-#12.sca.csv
# RESS-IoT-N=2000-#11.sca.csv
# RESS-IoT-N=500-#13.sca.csv
# RESS-IoT-N=5000-#17.sca.csv
# DQ-N=5000-#15.sca.csv
# DQ-N=10-#9.sca.csv
# RESS-IoT-N=4000-#3.sca.csv
# DQExp-N=3000-#0.sca.csv
# RESS-IoT-N=3000-#13.sca.csv
# DQ-N=3000-#8.sca.csv
# RESS-IoT-N=2000-#8.sca.csv
# RESS-IoT-N=3000-#1.sca.csv
# RESS-IoT-N=1000-#12.sca.csv
# RESS-IoT-N=100-#7.sca.csv
# RESS-IoT-N=3000-#9.sca.csv
# DQ-N=3000-#9.sca.csv
# RESS-IoT-N=2000-#14.sca.csv
# DQ-N=500-#5.sca.csv
# RESS-IoT-N=5000-#19.sca.csv
# RESS-IoT-N=4000-#11.sca.csv
# RESS-IoT-N=10-#9.sca.csv
# RESS-IoT-N=500-#5.sca.csv
# RESS-IoT-N=10-#12.sca.csv
# DQ-N=2000-#3.sca.csv
# RESS-IoT-N=3000-#17.sca.csv
# RESS-IoT-N=3000-#8.sca.csv
# RESS-IoT-N=5000-#18.sca.csv
# DQ-N=500-#15.sca.csv
# RESS-IoT-N=10-#13.sca.csv
# DQ-N=3000-#11.sca.csv
# RESS-IoT-N=500-#18.sca.csv
# RESS-IoT-N=10-#14.sca.csv
# RESS-IoT-N=5000-#6.sca.csv
# RESS-IoT-N=10-#10.sca.csv
# RESS-IoT-N=2000-#2.sca.csv
# RESS-IoT-N=5000-#16.sca.csv
# DQ-N=3000-#18.sca.csv
# RESS-IoT-N=2000-#7.sca.csv
# DQ-N=10-#1.sca.csv
# RESS-IoT-N=5000-#14.sca.csv
# RESS-IoT-N=4000-#7.sca.csv
# DQ-N=1000-#1.sca.csv
# RESS-IoT-N=1000-#15.sca.csv
# RESS-IoT-N=100-#13.sca.csv
# RESS-IoT-N=2000-#20.sca.csv
# RESS-IoT-N=3000-#14.sca.csv
# RESS-IoT-N=1000-#17.sca.csv
# DQ-N=100-#8.sca.csv
# RESS-IoT-N=4000-#10.sca.csv
# DQ-N=500-#2.sca.csv
# RESS-IoT-N=10-#8.sca.csv
# DQ-N=1000-#11.sca.csv
# DQ-N=5000-#17.sca.csv
# DQ-N=10-#15.sca.csv
# DQ-N=5000-#14.sca.csv
# RESS-IoT-N=4000-#8.sca.csv
# DQ-N=4000-#19.sca.csv
# RESS-IoT-N=2000-#1.sca.csv
# DQ-N=10-#5.sca.csv
# DQ-N=10-#16.sca.csv
# DQ-N=10-#2.sca.csv
# DQ-N=4000-#15.sca.csv
# DQ-N=3000-#2.sca.csv
# RESS-IoT-N=10-#0.sca.csv
# RESS-IoT-N=3000-#16.sca.csv
# RESS-IoT-N=4000-#19.sca.csv
# DQ-N=5000-#19.sca.csv
# RESS-IoT-N=100-#17.sca.csv
# DQ-N=3000-#12.sca.csv
# DQ-N=500-#1.sca.csv
# RESS-IoT-N=4000-#2.sca.csv
# RESS-IoT-N=5000-#10.sca.csv
# RESS-IoT-N=10-#3.sca.csv
# DQ-N=1000-#13.sca.csv
# RESS-IoT-N=10-#18.sca.csv
# RESS-IoT-N=1000-#11.sca.csv
# DQ-N=2000-#1.sca.csv
# DQ-N=2000-#11.sca.csv
# DQ-N=1000-#8.sca.csv
# RESS-IoT-N=3000-#11.sca.csv
# RESS-IoT-N=2000-#18.sca.csv
# DQ-N=2000-#8.sca.csv
# DQ-N=500-#8.sca.csv
# DQ-N=500-#9.sca.csv
# RESS-IoT-N=1000-#16.sca.csv
# DQ-N=500-#7.sca.csv
# DQ-N=10-#10.sca.csv
# DQ-N=1000-#17.sca.csv
# DQ-N=1000-#5.sca.csv
# RESS-IoT-N=3000-#2.sca.csv
# RESS-IoT-N=2000-#0.sca.csv
# RESS-IoT-N=500-#11.sca.csv
# DQ-N=5000-#18.sca.csv
# DQ-N=500-#4.sca.csv
# DQ-N=4000-#16.sca.csv
# RESS-IoT-N=500-#14.sca.csv
# DQExp-N=500-#0.sca.csv
# RESS-IoT-N=3000-#3.sca.csv
# RESS-IoT-N=500-#16.sca.csv
# DQ-N=3000-#1.sca.csv
# DQ-N=10-#12.sca.csv
# RESS-IoT-N=100-#1.sca.csv
# RESS-IoT-N=1000-#3.sca.csv
# DQ-N=100-#16.sca.csv
# RESS-IoT-N=4000-#1.sca.csv
# RESS-IoT-N=4000-#20.sca.csv
# DQ-N=4000-#6.sca.csv
# DQ-N=100-#20.sca.csv
# RESS-IoT-N=10-#1.sca.csv
# DQ-N=10-#14.sca.csv
# RESS-IoT-N=5000-#0.sca.csv
# DQ-N=5000-#3.sca.csv
# RESS-IoT-N=100-#14.sca.csv
# DQ-N=500-#17.sca.csv
# RESS-IoT-N=4000-#16.sca.csv
# RESS-IoT-N=3000-#20.sca.csv
# RESS-IoT-N=10-#2.sca.csv
# RESS-IoT-N=1000-#8.sca.csv
# DQ-N=2000-#6.sca.csv
# DQExp-N=1000-#0.sca.csv
# RESS-IoT-N=100-#4.sca.csv
# DQ-N=100-#15.sca.csv
# DQ-N=4000-#14.sca.csv
# RESS-IoT-N=500-#12.sca.csv
# RESS-IoT-N=5000-#1.sca.csv
# DQ-N=5000-#2.sca.csv
# RESS-IoT-N=1000-#1.sca.csv
# DQ-N=1000-#12.sca.csv
# DQ-N=3000-#15.sca.csv
# DQ-N=3000-#0.sca.csv
# RESS-IoT-N=3000-#19.sca.csv
# DQ-N=500-#6.sca.csv
# RESS-IoT-N=100-#20.sca.csv
# DQ-N=4000-#13.sca.csv
# DQ-N=500-#12.sca.csv
# DQ-N=2000-#2.sca.csv
# RESS-IoT-N=4000-#13.sca.csv
# DQExp-N=5000-#0.sca.csv
# RESS-IoT-N=4000-#6.sca.csv
# DQ-N=500-#14.sca.csv
# RESS-IoT-N=1000-#20.sca.csv
# RESS-IoT-N=2000-#13.sca.csv
# DQ-N=4000-#8.sca.csv
# DQ-N=10-#13.sca.csv
# RESS-IoT-N=500-#17.sca.csv
# RESS-IoT-N=10-#11.sca.csv
# DQ-N=5000-#11.sca.csv
# DQ-N=500-#11.sca.csv
# DQ-N=2000-#18.sca.csv
# RESS-IoT-N=100-#10.sca.csv
# DQ-N=100-#9.sca.csv
# RESS-IoT-N=1000-#5.sca.csv
# DQ-N=3000-#19.sca.csv
# DQ-N=2000-#13.sca.csv
# DQ-N=10-#4.sca.csv
# DQ-N=100-#10.sca.csv
# RESS-IoT-N=2000-#12.sca.csv
# RESS-IoT-N=500-#9.sca.csv
# DQ-N=4000-#20.sca.csv
# RESS-IoT-N=100-#9.sca.csv
# DQ-N=3000-#3.sca.csv
# RESS-IoT-N=100-#19.sca.csv
# DQ-N=3000-#17.sca.csv
# RESS-IoT-N=3000-#7.sca.csv
# RESS-IoT-N=500-#15.sca.csv
# RESS-IoT-N=3000-#10.sca.csv
# DQ-N=4000-#4.sca.csv
# DQ-N=1000-#4.sca.csv
# RESS-IoT-N=3000-#12.sca.csv
# DQ-N=5000-#5.sca.csv
# DQ-N=100-#5.sca.csv
# RESS-IoT-N=5000-#5.sca.csv
# DQ-N=2000-#20.sca.csv
# DQ-N=2000-#7.sca.csv
# RESS-IoT-N=500-#7.sca.csv
# RESS-IoT-N=4000-#14.sca.csv
# RESS-IoT-N=5000-#12.sca.csv
# DQ-N=100-#11.sca.csv
# RESS-IoT-N=10-#15.sca.csv
# RESS-IoT-N=100-#11.sca.csv
# DQ-N=4000-#12.sca.csv
# RESS-IoT-N=5000-#15.sca.csv
# RESS-IoT-N=1000-#6.sca.csv
# DQ-N=10-#0.sca.csv
# DQ-N=1000-#20.sca.csv
# DQ-N=3000-#4.sca.csv
# DQ-N=5000-#20.sca.csv
# DQ-N=1000-#14.sca.csv
# DQ-N=10-#11.sca.csv
# RESS-IoT-N=100-#3.sca.csv
# DQ-N=10-#3.sca.csv
# DQ-N=4000-#5.sca.csv
# DQ-N=5000-#1.sca.csv
# DQ-N=10-#20.sca.csv
# DQ-N=10-#17.sca.csv
# DQ-N=4000-#3.sca.csv
# DQ-N=500-#10.sca.csv
# DQ-N=5000-#7.sca.csv
# DQ-N=4000-#17.sca.csv
# DQ-N=10-#19.sca.csv
# RESS-IoT-N=100-#6.sca.csv
# DQ-N=2000-#17.sca.csv
# RESS-IoT-N=100-#16.sca.csv
# RESS-IoT-N=1000-#18.sca.csv
# RESS-IoT-N=5000-#9.sca.csv
# DQ-N=4000-#18.sca.csv
# DQ-N=4000-#9.sca.csv
# DQ-N=2000-#14.sca.csv
# DQ-N=1000-#9.sca.csv
# RESS-IoT-N=3000-#4.sca.csv
# DQ-N=2000-#10.sca.csv
# DQ-N=10-#7.sca.csv
# RESS-IoT-N=5000-#2.sca.csv
# DQ-N=100-#6.sca.csv
# RESS-IoT-N=5000-#4.sca.csv
# RESS-IoT-N=4000-#5.sca.csv
# RESS-IoT-N=1000-#2.sca.csv
# RESS-IoT-N=2000-#19.sca.csv
# DQ-N=500-#0.sca.csv
# RESS-IoT-N=2000-#10.sca.csv
# RESS-IoT-N=500-#8.sca.csv
# DQExp-N=100-#0.sca.csv
# RESS-IoT-N=2000-#16.sca.csv
# RESS-IoT-N=2000-#4.sca.csv
# RESS-IoT-N=5000-#11.sca.csv
# DQ-N=3000-#16.sca.csv
# RESS-IoT-N=100-#18.sca.csv
# DQ-N=5000-#13.sca.csv
# DQ-N=500-#16.sca.csv
# DQ-N=2000-#15.sca.csv
# RESS-IoT-N=100-#12.sca.csv
# DQ-N=100-#17.sca.csv
# RESS-IoT-N=2000-#3.sca.csv
# RESS-IoT-N=1000-#10.sca.csv
# RESS-IoT-N=2000-#9.sca.csv
# DQ-N=1000-#7.sca.csv
# RESS-IoT-N=500-#20.sca.csv
# DQ-N=4000-#7.sca.csv
# DQ-N=4000-#2.sca.csv
# RESS-IoT-N=1000-#0.sca.csv
# DQ-N=10-#18.sca.csv
# DQ-N=10-#8.sca.csv
# RESS-IoT-N=10-#7.sca.csv
# DQ-N=5000-#12.sca.csv
# RESS-IoT-N=10-#19.sca.csv
# DQ-N=100-#18.sca.csv
# DQ-N=1000-#2.sca.csv
# DQ-N=2000-#0.sca.csv
# RESS-IoT-N=10-#20.sca.csv
# RESS-IoT-N=10-#5.sca.csv
# RESS-IoT-N=3000-#18.sca.csv
# DQ-N=3000-#20.sca.csv
# RESS-IoT-N=10-#16.sca.csv
# RESS-IoT-N=4000-#18.sca.csv
# RESS-IoT-N=1000-#14.sca.csv
# RESS-IoT-N=10-#6.sca.csv
# DQ-N=500-#18.sca.csv
# DQ-N=100-#4.sca.csv
# DQ-N=500-#19.sca.csv
# RESS-IoT-N=2000-#15.sca.csv
# DQ-N=1000-#18.sca.csv
# RESS-IoT-N=1000-#19.sca.csv
# RESS-IoT-N=2000-#6.sca.csv
# RESS-IoT-N=100-#5.sca.csv
# DQ-N=2000-#5.sca.csv
# DQ-N=1000-#10.sca.csv
# DQ-N=500-#3.sca.csv
# DQ-N=2000-#19.sca.csv
# DQ-N=10-#6.sca.csv
# DQ-N=5000-#4.sca.csv
# DQ-N=100-#19.sca.csv
# DQ-N=5000-#6.sca.csv
# RESS-IoT-N=100-#0.sca.csv
# RESS-IoT-N=2000-#5.sca.csv
# DQ-N=3000-#7.sca.csv
# DQ-N=3000-#13.sca.csv
# RESS-IoT-N=500-#3.sca.csv
# RESS-IoT-N=1000-#13.sca.csv
# RESS-IoT-N=1000-#4.sca.csv

# %%
def get_throughput_bytes_per_hour(df):
    # Throughput B / hr
    sim_time_hours = float(df.loc[df['name'] == 'simulated time'].value.iloc[0]) / 60 / 60
    bytes_per_data_packet = int(df.loc[df['name'] == 'dataPacketLenBits'].value.iloc[0]) / 8
    num_data_packets = int(df.loc[df['name'] == 'numDataPacketsReceived'].value.iloc[0])

    return (num_data_packets * bytes_per_data_packet) / sim_time_hours

def get_jfi(df):
    # Jain's Fairness Index
    num_nodes = int(df.loc[df['name'] == 'nrOfNodes'].value.iloc[0])
    denominator = num_nodes * df[df['name'].str.startswith('numDataPacketsReceivedByNodeId', na=False)].value.astype(int).pow(2).sum()
    numerator =  df[df['name'].str.startswith('numDataPacketsReceivedByNodeId', na=False)].value.astype(int).sum() ** 2.0
    jfi = numerator / denominator if denominator != 0 else 0
    return jfi

def get_overhead_bytes(df):
    # Total bytes of overhead (Beacon, RTS, VCTS) or (ARS, FBP)
    possible_keys = [
        ('numARSPacketsSent', 'arsPacketLenBits'),
        ('numFBPPacketsSent', 'fbpPacketLenBits'),
        ('numRTSPacketsSent', 'rtsPacketLenBits'),
        ('numBeaconPacketsSent', 'beaconPacketLenBits'),
        ('numVCTSPacketsSent', 'vctsPacketLenBits'),
    ]
    
    overhead_bits = 0
    for key in possible_keys:
        try:
            total_num_packets = df.loc[df['name'] == key[0]].value.astype(int).sum()
            bits_per_packet = int(df.loc[df['name'] == key[1]].value.iloc[0])
            overhead_bits += (total_num_packets * bits_per_packet)
        except IndexError:
            pass

    return overhead_bits / 8

def get_data_bytes(df):
    bits_per_data_packet = int(df.loc[df['name'] == 'dataPacketLenBits'].value.iloc[0])
    num_data_packets = int(df.loc[df['name'] == 'numDataPacketsReceived'].value.iloc[0])

    return bits_per_data_packet * num_data_packets / 8

def get_avg_delay(df_sca):
    num_data_packets = int(df_sca.loc[df_sca['name'] == 'numDataPacketsReceived'].value.iloc[0])
    total_delay = float(df_sca.loc[df_sca['name'] == 'totalPacketDelay'].value.iloc[0])
    
    return total_delay / num_data_packets

def get_energy_satellite_DQ(df_sca):
    p_rx = 25.74 / 1000 # W
    p_tx = 389.4 / 1000 # W
    
    num_rounds = int(df_sca.loc[df_sca['name'] == "numFBPPacketsSent"].value.iloc[0])
    
    # Sat always sends a FBP
    t_fbp = float(df_sca.loc[df_sca['name'] == "fbpPacketTime"].value.iloc[0])
    e_fbp = num_rounds * p_tx * t_fbp
    
    # Sat always listens for all contention slots
    t_ars = float(df_sca.loc[df_sca['name'] == "arsPacketTime"].value.iloc[0])
    n_slots = int(df_sca.loc[df_sca['name'] == "numContentionSlots"].value.iloc[0])
    e_ars = num_rounds * p_rx * t_ars * n_slots
    
    # Sat only listens when a data packet will be sent len(dtq) != 0
    t_data = float(df_sca.loc[df_sca['name'] == "dataPacketTime"].value.iloc[0])
    num_data_packets = float(df_sca.loc[df_sca['name'] == "numDataPacketsReceived"].value.iloc[0])
    e_data = num_data_packets * p_rx * t_data
    
    return e_fbp + e_ars + e_data

def get_energy_node_DQ(df_sca):
    p_rx = 25.74 / 1000 # W
    p_tx = 389.4 / 1000 # W
    
    num_rounds = int(df_sca.loc[df_sca['name'] == "numFBPPacketsSent"].value.iloc[0])
    num_nodes = int(df_sca.loc[df_sca['name'] == 'nrOfNodes'].value.iloc[0])

    # Nodes always listen for FBP
    t_fbp = float(df_sca.loc[df_sca['name'] == "fbpPacketTime"].value.iloc[0])
    e_fbp = num_nodes * num_rounds * p_rx * t_fbp
    
    # Nodes only send ARS when the constraints are met
    t_ars = float(df_sca.loc[df_sca['name'] == "arsPacketTime"].value.iloc[0])
    total_num_ars_packets_sent = df_sca.loc[df_sca['name'] == "numARSPacketsSent"].value.astype(int).sum()
    e_ars = total_num_ars_packets_sent * p_tx * t_ars
    
    # Only one or zero data packets can be sent each round
    t_data = float(df_sca.loc[df_sca['name'] == "dataPacketTime"].value.iloc[0])
    num_data_packets = float(df_sca.loc[df_sca['name'] == "numDataPacketsReceived"].value.iloc[0])
    e_data = num_data_packets * p_tx * t_data
    
    return e_fbp + e_ars + e_data

def get_energy_satellite_RESSIOT(df_sca):
    p_rx = 25.74 / 1000 # W
    p_tx = 389.4 / 1000 # W
        
    num_rounds = int(df_sca.loc[df_sca['name'] == "numBeaconPacketsSent"].value.iloc[0])

    t_beacon = float(df_sca.loc[df_sca['name'] == "beaconPacketTime"].value.iloc[0])
    w_rx = float(df_sca.loc[df_sca['name'] == "wrx"].value.iloc[0])
    e_rp_sat = num_rounds * ((p_tx * t_beacon) + (p_rx * w_rx))
    
    t_vcts = float(df_sca.loc[df_sca['name'] == "vctsPacketTime"].value.iloc[0])
    t_data = float(df_sca.loc[df_sca['name'] == "dataPacketTime"].value.iloc[0])
    num_data_packets = float(df_sca.loc[df_sca['name'] == "numDataPacketsReceived"].value.iloc[0])
    e_tp_sat = (num_rounds * p_tx * t_vcts) + (num_data_packets * p_rx * t_data)
    
    return e_rp_sat + e_tp_sat

def get_energy_node_RESSIOT(df_sca):
    p_rx = 25.74 / 1000 # W
    p_tx = 389.4 / 1000 # W
        
    num_rounds = int(df_sca.loc[df_sca['name'] == "numBeaconPacketsSent"].value.iloc[0])
    num_nodes = int(df_sca.loc[df_sca['name'] == 'nrOfNodes'].value.iloc[0])

    t_beacon = float(df_sca.loc[df_sca['name'] == "beaconPacketTime"].value.iloc[0])
    t_rts = float(df_sca.loc[df_sca['name'] == "rtsPacketTime"].value.iloc[0])
    total_num_rts_packets_sent = df_sca.loc[df_sca['name'] == "numRTSPacketsSent"].value.astype(int).sum()
    e_rp_nodes = (num_nodes * num_rounds * p_rx * t_beacon) + (total_num_rts_packets_sent * p_tx * t_rts)
    
    t_vcts = float(df_sca.loc[df_sca['name'] == "vctsPacketTime"].value.iloc[0])
    t_data = float(df_sca.loc[df_sca['name'] == "dataPacketTime"].value.iloc[0])
    num_data_packets = float(df_sca.loc[df_sca['name'] == "numDataPacketsReceived"].value.iloc[0])
    e_tp_nodes = (num_rounds * num_nodes * p_rx * t_vcts) + (num_data_packets * p_tx * t_data)

    return e_rp_nodes + e_tp_nodes

def get_avg_energy_efficiency_node(key, df_sca):
    if key == "RESS-IoT": 
        e_nodes = get_energy_node_RESSIOT(df_sca)
    elif key == "DQ":
        e_nodes = get_energy_node_DQ(df_sca)

    num_nodes = int(df_sca.loc[df_sca['name'] == 'nrOfNodes'].value.iloc[0])
    
    return (get_data_bytes(df_sca) / num_nodes ) / (e_nodes / num_nodes)
    
def get_energy_efficiency_satellite(key, df_sca):
    if key == "RESS-IoT": 
        e_sat = get_energy_satellite_RESSIOT(df_sca)
    elif key == "DQ":
        e_sat = get_energy_satellite_DQ(df_sca)
    
    return get_data_bytes(df_sca) / e_sat

def get_energy_efficiency_network(key, df_sca):
    if key == "RESS-IoT": 
        e_network = get_energy_satellite_RESSIOT(df_sca) + get_energy_node_RESSIOT(df_sca)
    elif key == "DQ":
        e_network = get_energy_satellite_DQ(df_sca) + get_energy_node_DQ(df_sca)
    
    return get_data_bytes(df_sca) / e_network

# %%
metrics = {}

for key in dfs:
    metrics[key] = {}
    
    for node_count in dfs[key]["SCA"]:
        print(key, node_count)
        
        metrics[key][node_count] = {
            "Average Delay [seconds]": [],
            "Jain Fairness Index": [],
            "Throughput [bytes / hour]": [],
            "Overhead": [],
            "Data": [],
            "Satellite Energy Efficiency [bytes / joule]": [],
            "Average Energy Efficiency per Node [bytes / joule]": [],
            "Network Energy Efficiency [bytes / joule]": [],
        }
        
        for df_sca in dfs[key]["SCA"][node_count]:            
            # metrics[key][node_count]["Average Delay [seconds]"].append(get_avg_delay(df_sca))
            metrics[key][node_count]["Jain Fairness Index"].append(get_jfi(df_sca))
            metrics[key][node_count]["Throughput [bytes / hour]"].append(get_throughput_bytes_per_hour(df_sca))
            metrics[key][node_count]["Overhead"].append(get_overhead_bytes(df_sca))
            metrics[key][node_count]["Data"].append(get_data_bytes(df_sca))
            metrics[key][node_count]["Satellite Energy Efficiency [bytes / joule]"].append(get_energy_efficiency_satellite(key, df_sca))
            metrics[key][node_count]["Average Energy Efficiency per Node [bytes / joule]"].append(get_avg_energy_efficiency_node(key, df_sca))
            metrics[key][node_count]["Network Energy Efficiency [bytes / joule]"].append(get_energy_efficiency_network(key, df_sca))
    
pprint.pprint(metrics)
# Out:
# RESS-IoT 10
# RESS-IoT 100
# RESS-IoT 500
# RESS-IoT 1000
# RESS-IoT 2000
# RESS-IoT 3000
# RESS-IoT 4000
# RESS-IoT 5000
# DQ 10
# DQ 100
# DQ 500
# DQ 1000
# DQ 2000
# DQ 3000
# DQ 4000
# DQ 5000
# DQExp 10
# DQExp 100
# DQExp 500
# DQExp 1000
# DQExp 2000
# DQExp 3000
# DQExp 4000
# DQExp 5000
# {'DQ': {10: {'Average Delay [seconds]': [],
#              'Average Energy Efficiency per Node [bytes / joule]': [101.18904463588976,
#                                                                     106.18628631350344,
#                                                                     105.1782452547183,
#                                                                     107.12708476612676,
#                                                                     101.72260232190409,
#                                                                     94.68752703032543,
#                                                                     104.30369418857056,
#                                                                     98.24386265167875,
#                                                                     101.8266022995057,
#                                                                     99.19672995259138,
#                                                                     99.54424837377455,
#                                                                     104.08812780328752,
#                                                                     110.79945469272917,
#                                                                     101.35680132079226,
#                                                                     104.46837667450747,
#                                                                     103.25147984302829,
#                                                                     99.75375009148608,
#                                                                     104.46837667450747,
#                                                                     96.38335879713684,
#                                                                     103.80532273337688,
#                                                                     106.77347005966125],
#              'Data': [4473.0,
#                       4977.0,
#                       4662.0,
#                       5103.0,
#                       4536.0,
#                       3654.0,
#                       4977.0,
#                       3906.0,
#                       4599.0,
#                       4095.0,
#                       4410.0,
#                       4662.0,
#                       5670.0,
#                       4662.0,
#                       4788.0,
#                       4536.0,
#                       4032.0,
#                       4788.0,
#                       4032.0,
#                       4473.0,
#                       4977.0],
#              'Jain Fairness Index': [0.8706390328151986,
#                                      0.9245925925925926,
#                                      0.8719745222929937,
#                                      0.9150627615062762,
#                                      0.9062937062937063,
#                                      0.9191256830601093,
#                                      0.970606531881804,
#                                      0.8736363636363637,
#                                      0.9332749562171628,
#                                      0.9008528784648188,
#                                      0.8909090909090909,
#                                      0.8747603833865815,
#                                      0.916289592760181,
#                                      0.8719745222929937,
#                                      0.9468852459016394,
#                                      0.9,
#                                      0.9481481481481482,
#                                      0.8751515151515151,
#                                      0.9706161137440759,
#                                      0.8953818827708704,
#                                      0.9191458026509572],
#              'Network Energy Efficiency [bytes / joule]': [60.71602275056642,
#                                                            65.33523234003171,
#                                                            63.26319422677952,
#                                                            66.42536750471601,
#                                                            61.3622551086059,
#                                                            53.153077127215056,
#                                                            64.74828486465351,
#                                                            56.183786221323786,
#                                                            61.849281333924495,
#                                                            57.84654787044579,
#                                                            59.92325469113941,
#                                                            62.86717050169323,
#                                                            71.09401862738069,
#                                                            61.86034142549453,
#                                                            63.77063202104105,
#                                                            61.78421879939818,
#                                                            57.4189347985977,
#                                                            63.77063202104105,
#                                                            56.531318007167954,
#                                                            61.64832205968327,
#                                                            65.82658965550662],
#              'Overhead': [2285.0,
#                           2281.0,
#                           2253.0,
#                           2279.0,
#                           2280.0,
#                           2273.0,
#                           2300.0,
#                           2249.0,
#                           2281.0,
#                           2254.0,
#                           2289.0,
#                           2268.0,
#                           2269.0,
#                           2307.0,
#                           2275.0,
#                           2267.0,
#                           2252.0,
#                           2275.0,
#                           2281.0,
#                           2249.0,
#                           2256.0],
#              'Satellite Energy Efficiency [bytes / joule]': [151.799792800959,
#                                                              169.82929478693876,
#                                                              158.7475523659957,
#                                                              174.83183644552167,
#                                                              154.65496966615075,
#                                                              121.17491477481316,
#                                                              170.73481021150246,
#                                                              131.2340025325159,
#                                                              157.53687392714482,
#                                                              138.77057122493127,
#                                                              150.55188661141642,
#                                                              158.7475523659957,
#                                                              198.39042903002,
#                                                              158.7475523659957,
#                                                              163.6949286372332,
#                                                              153.83972467511825,
#                                                              135.2965409862276,
#                                                              163.6949286372332,
#                                                              136.72269220730576,
#                                                              151.799792800959,
#                                                              171.65003366162912],
#              'Throughput [bytes / hour]': [40257.0,
#                                            44793.0,
#                                            41958.0,
#                                            45927.0,
#                                            40824.0,
#                                            32886.0,
#                                            44793.0,
#                                            35154.0,
#                                            41391.0,
#                                            36855.0,
#                                            39690.0,
#                                            41958.0,
#                                            51030.0,
#                                            41958.0,
#                                            43092.0,
#                                            40824.0,
#                                            36288.0,
#                                            43092.0,
#                                            36288.0,
#                                            40257.0,
#                                            44793.0]},
#         100: {'Average Delay [seconds]': [],
#               'Average Energy Efficiency per Node [bytes / joule]': [43.728633042205864,
#                                                                      42.766804484795195,
#                                                                      42.12282615229884,
#                                                                      42.536826493383494,
#                                                                      42.78857669711976,
#                                                                      43.089161069751974,
#                                                                      42.51685370236931,
#                                                                      43.30196926451621,
#                                                                      43.899512449525844,
#                                                                      42.015640963060534,
#                                                                      42.971663135867445,
#                                                                      42.90751832085378,
#                                                                      42.607043767285155,
#                                                                      43.55907877725996,
#                                                                      42.89824086520725,
#                                                                      42.35620365265678,
#                                                                      42.784902000571314,
#                                                                      42.338845571289966,
#                                                                      42.554973540439356,
#                                                                      42.78857669711976,
#                                                                      42.0881273380597],
#               'Data': [9387.0,
#                        9387.0,
#                        9198.0,
#                        9261.0,
#                        9324.0,
#                        9450.0,
#                        9324.0,
#                        9513.0,
#                        9387.0,
#                        9198.0,
#                        9324.0,
#                        9450.0,
#                        9324.0,
#                        9387.0,
#                        9324.0,
#                        9261.0,
#                        9387.0,
#                        9198.0,
#                        9261.0,
#                        9324.0,
#                        9261.0],
#               'Jain Fairness Index': [0.7900711743772242,
#                                       0.7375747508305648,
#                                       0.7250340136054422,
#                                       0.7275757575757575,
#                                       0.7553103448275862,
#                                       0.7450331125827815,
#                                       0.7158169934640523,
#                                       0.6765875370919882,
#                                       0.7138585209003215,
#                                       0.6745569620253165,
#                                       0.7158169934640523,
#                                       0.6944444444444444,
#                                       0.7252980132450331,
#                                       0.6627164179104478,
#                                       0.6931645569620253,
#                                       0.7375085324232082,
#                                       0.6666966966966967,
#                                       0.670314465408805,
#                                       0.6052941176470589,
#                                       0.7301333333333333,
#                                       0.6648923076923077],
#               'Network Energy Efficiency [bytes / joule]': [38.93576381522561,
#                                                             38.17137992779661,
#                                                             37.58433606963746,
#                                                             37.93871423444809,
#                                                             38.163939548566205,
#                                                             38.45276727817227,
#                                                             37.94763019862309,
#                                                             38.64686534719163,
#                                                             39.07117961929284,
#                                                             37.498980350489774,
#                                                             38.309521016928976,
#                                                             38.308045388914174,
#                                                             38.019460350776704,
#                                                             38.801283437445356,
#                                                             38.251155351031315,
#                                                             37.79496448227068,
#                                                             38.185796477546155,
#                                                             37.7562185665975,
#                                                             37.95314937386833,
#                                                             38.163939548566205,
#                                                             37.58137081482058],
#               'Overhead': [3190.0,
#                            3346.0,
#                            3337.0,
#                            3307.0,
#                            3304.0,
#                            3331.0,
#                            3349.0,
#                            3334.0,
#                            3163.0,
#                            3355.0,
#                            3274.0,
#                            3361.0,
#                            3334.0,
#                            3217.0,
#                            3286.0,
#                            3337.0,
#                            3343.0,
#                            3301.0,
#                            3304.0,
#                            3304.0,
#                            3382.0],
#               'Satellite Energy Efficiency [bytes / joule]': [355.23767652778747,
#                                                               355.23767652778747,
#                                                               348.8293299040424,
#                                                               350.9684874780368,
#                                                               353.10460085475364,
#                                                               357.367720972277,
#                                                               353.10460085475364,
#                                                               359.49474064497116,
#                                                               355.23767652778747,
#                                                               348.8293299040424,
#                                                               353.10460085475364,
#                                                               357.367720972277,
#                                                               353.10460085475364,
#                                                               355.23767652778747,
#                                                               353.10460085475364,
#                                                               350.9684874780368,
#                                                               355.23767652778747,
#                                                               348.8293299040424,
#                                                               350.9684874780368,
#                                                               353.10460085475364,
#                                                               350.9684874780368],
#               'Throughput [bytes / hour]': [84483.0,
#                                             84483.0,
#                                             82782.0,
#                                             83349.0,
#                                             83916.0,
#                                             85050.0,
#                                             83916.0,
#                                             85617.0,
#                                             84483.0,
#                                             82782.0,
#                                             83916.0,
#                                             85050.0,
#                                             83916.0,
#                                             84483.0,
#                                             83916.0,
#                                             83349.0,
#                                             84483.0,
#                                             82782.0,
#                                             83349.0,
#                                             83916.0,
#                                             83349.0]},
#         500: {'Average Delay [seconds]': [],
#               'Average Energy Efficiency per Node [bytes / joule]': [10.48300318978679,
#                                                                      10.104349870701355,
#                                                                      10.285575790162726,
#                                                                      10.349162732381773,
#                                                                      10.616962366739426,
#                                                                      10.368185960909027,
#                                                                      10.699876416663225,
#                                                                      10.48147832743337,
#                                                                      10.867691405095343,
#                                                                      10.222988015093314,
#                                                                      10.603543588668945,
#                                                                      10.010175814602375,
#                                                                      10.737454690963006,
#                                                                      10.441757965786657,
#                                                                      9.991383979972644,
#                                                                      10.100408504702559,
#                                                                      10.557189534525179,
#                                                                      10.623073045187619,
#                                                                      10.068212230129568,
#                                                                      10.405731128197635,
#                                                                      10.737454690963006],
#               'Data': [8505.0,
#                        8190.0,
#                        8316.0,
#                        8379.0,
#                        8568.0,
#                        8379.0,
#                        8631.0,
#                        8442.0,
#                        8757.0,
#                        8253.0,
#                        8568.0,
#                        8127.0,
#                        8631.0,
#                        8442.0,
#                        8064.0,
#                        8190.0,
#                        8505.0,
#                        8568.0,
#                        8127.0,
#                        8379.0,
#                        8631.0],
#               'Jain Fairness Index': [0.17955665024630543,
#                                       0.169,
#                                       0.18536170212765957,
#                                       0.16927272727272727,
#                                       0.17449056603773586,
#                                       0.1742758620689655,
#                                       0.20512568306010928,
#                                       0.19731868131868133,
#                                       0.18849756097560977,
#                                       0.1642200956937799,
#                                       0.19068041237113403,
#                                       0.1799027027027027,
#                                       0.19054822335025381,
#                                       0.19731868131868133,
#                                       0.18204444444444445,
#                                       0.18369565217391304,
#                                       0.19285714285714287,
#                                       0.18496,
#                                       0.17797860962566844,
#                                       0.17257560975609756,
#                                       0.18491625615763546],
#               'Network Energy Efficiency [bytes / joule]': [10.144233051536375,
#                                                             9.778612375951706,
#                                                             9.952742354425894,
#                                                             10.01449500902485,
#                                                             10.273776272721694,
#                                                             10.032306738397711,
#                                                             10.35362510504683,
#                                                             10.142482459502745,
#                                                             10.517133913063603,
#                                                             9.891921818517465,
#                                                             10.261210466277165,
#                                                             9.686408823078022,
#                                                             10.390750571820693,
#                                                             10.10528529157631,
#                                                             9.668392837258018,
#                                                             9.773108014871465,
#                                                             10.215592936093127,
#                                                             10.279498182473354,
#                                                             9.742556473422297,
#                                                             10.06933504916221,
#                                                             10.390750571820693],
#               'Overhead': [5665.0,
#                            5686.0,
#                            5602.0,
#                            5629.0,
#                            5639.0,
#                            5581.0,
#                            5618.0,
#                            5606.0,
#                            5694.0,
#                            5572.0,
#                            5672.0,
#                            5616.0,
#                            5649.0,
#                            5705.0,
#                            5593.0,
#                            5574.0,
#                            5603.0,
#                            5624.0,
#                            5587.0,
#                            5609.0,
#                            5649.0],
#               'Satellite Energy Efficiency [bytes / joule]': [313.90614292747995,
#                                                               303.3317388669831,
#                                                               307.57031840801375,
#                                                               309.6851930967057,
#                                                               317.8342536400977,
#                                                               309.6851930967057,
#                                                               319.9482727481971,
#                                                               313.5973625124155,
#                                                               326.0434263458543,
#                                                               305.4525023782529,
#                                                               317.8342536400977,
#                                                               299.48283138626806,
#                                                               321.8023880017021,
#                                                               313.5973625124155,
#                                                               299.0813447525764,
#                                                               301.59558686186267,
#                                                               315.71728561970497,
#                                                               317.8342536400977,
#                                                               301.20802171666,
#                                                               311.4744781263754,
#                                                               321.8023880017021],
#               'Throughput [bytes / hour]': [76545.0,
#                                             73710.0,
#                                             74844.0,
#                                             75411.0,
#                                             77112.0,
#                                             75411.0,
#                                             77679.0,
#                                             75978.0,
#                                             78813.0,
#                                             74277.0,
#                                             77112.0,
#                                             73143.0,
#                                             77679.0,
#                                             75978.0,
#                                             72576.0,
#                                             73710.0,
#                                             76545.0,
#                                             77112.0,
#                                             73143.0,
#                                             75411.0,
#                                             77679.0]},
#         1000: {'Average Delay [seconds]': [],
#                'Average Energy Efficiency per Node [bytes / joule]': [5.055674588010079,
#                                                                       5.0391836552816365,
#                                                                       5.05850711152192,
#                                                                       4.934276328885721,
#                                                                       5.0773632581460255,
#                                                                       5.037995931821242,
#                                                                       5.117625461841155,
#                                                                       4.9627425516952455,
#                                                                       4.897948162401571,
#                                                                       5.050045575943575,
#                                                                       5.039777727043762,
#                                                                       4.90053639373668,
#                                                                       5.011767961282878,
#                                                                       5.196326004678084,
#                                                                       4.864711024479734,
#                                                                       4.841301193767557,
#                                                                       5.082453808834406,
#                                                                       5.175522970642786,
#                                                                       4.819472827258445,
#                                                                       5.156069228573662,
#                                                                       5.046023947802188],
#                'Data': [8001.0,
#                         7938.0,
#                         7938.0,
#                         7812.0,
#                         8001.0,
#                         7938.0,
#                         8064.0,
#                         7812.0,
#                         7749.0,
#                         8001.0,
#                         7938.0,
#                         7749.0,
#                         7938.0,
#                         8190.0,
#                         7686.0,
#                         7623.0,
#                         8001.0,
#                         8127.0,
#                         7623.0,
#                         8127.0,
#                         7938.0],
#                'Jain Fairness Index': [0.09895092024539877,
#                                        0.09230232558139535,
#                                        0.09563855421686747,
#                                        0.09152380952380952,
#                                        0.08813661202185792,
#                                        0.10584,
#                                        0.09990243902439025,
#                                        0.09375609756097561,
#                                        0.10019205298013245,
#                                        0.09323121387283237,
#                                        0.10048101265822784,
#                                        0.0845195530726257,
#                                        0.10048101265822784,
#                                        0.10304878048780487,
#                                        0.08653488372093024,
#                                        0.09569281045751633,
#                                        0.11123448275862069,
#                                        0.09296648044692737,
#                                        0.09325477707006369,
#                                        0.10466037735849057,
#                                        0.10048101265822784],
#                'Network Energy Efficiency [bytes / joule]': [4.9696016959221065,
#                                                              4.953537986923405,
#                                                              4.972693093856651,
#                                                              4.850472996776237,
#                                                              4.991040488023189,
#                                                              4.952390288733093,
#                                                              5.030554480966441,
#                                                              4.878451265487578,
#                                                              4.8147601529736015,
#                                                              4.964162617112674,
#                                                              4.954112035522796,
#                                                              4.817261190104596,
#                                                              4.926568555737742,
#                                                              5.1078174157822644,
#                                                              4.782033359533163,
#                                                              4.759262996482267,
#                                                              4.9959593323423785,
#                                                              5.08760140986303,
#                                                              4.737708833943189,
#                                                              5.068310488874622,
#                                                              4.960147588439936],
#                'Overhead': [8845.0,
#                             8873.0,
#                             8934.0,
#                             8893.0,
#                             8882.0,
#                             8885.0,
#                             8870.0,
#                             8855.0,
#                             8866.0,
#                             8902.0,
#                             8867.0,
#                             8839.0,
#                             8896.0,
#                             8864.0,
#                             8806.0,
#                             8897.0,
#                             8831.0,
#                             8940.0,
#                             8872.0,
#                             8876.0,
#                             8804.0],
#                'Satellite Energy Efficiency [bytes / joule]': [291.9001371642793,
#                                                                291.45417553533395,
#                                                                293.12697462561704,
#                                                                285.59215355094045,
#                                                                293.56478664606595,
#                                                                291.45417553533395,
#                                                                295.67248973589193,
#                                                                287.2242051445232,
#                                                                283.4837112442367,
#                                                                291.9001371642793,
#                                                                291.45417553533395,
#                                                                283.4837112442367,
#                                                                289.8003605627195,
#                                                                299.8791958599488,
#                                                                281.3723684453914,
#                                                                280.85728829703106,
#                                                                293.56478664606595,
#                                                                299.48283138626806,
#                                                                279.258119165164,
#                                                                297.7772908107245,
#                                                                291.45417553533395],
#                'Throughput [bytes / hour]': [72009.0,
#                                              71442.0,
#                                              71442.0,
#                                              70308.0,
#                                              72009.0,
#                                              71442.0,
#                                              72576.0,
#                                              70308.0,
#                                              69741.0,
#                                              72009.0,
#                                              71442.0,
#                                              69741.0,
#                                              71442.0,
#                                              73710.0,
#                                              69174.0,
#                                              68607.0,
#                                              72009.0,
#                                              73143.0,
#                                              68607.0,
#                                              73143.0,
#                                              71442.0]},
#         2000: {'Average Delay [seconds]': [],
#                'Average Energy Efficiency per Node [bytes / joule]': [1.6588962064183606,
#                                                                       1.4966220359179114,
#                                                                       1.5489794661844456,
#                                                                       1.5390232975119411,
#                                                                       1.6232288241463968,
#                                                                       1.4508266124053113,
#                                                                       1.468377975313329,
#                                                                       1.371673423250502,
#                                                                       1.7519193739275718,
#                                                                       1.6049818276332022,
#                                                                       1.4056307899659097,
#                                                                       1.5779080334165634,
#                                                                       1.7994117944817274,
#                                                                       1.405707418495387,
#                                                                       1.7533462947497345,
#                                                                       1.6409596607115484,
#                                                                       1.5415389215585389,
#                                                                       1.7537896049897364,
#                                                                       1.5315411788887052,
#                                                                       1.9232999871333794,
#                                                                       1.5955415391196515],
#                'Data': [5544.0,
#                         5040.0,
#                         5229.0,
#                         5166.0,
#                         5418.0,
#                         4914.0,
#                         4977.0,
#                         4662.0,
#                         5796.0,
#                         5355.0,
#                         4788.0,
#                         5292.0,
#                         5985.0,
#                         4788.0,
#                         5796.0,
#                         5481.0,
#                         5166.0,
#                         5796.0,
#                         5166.0,
#                         6300.0,
#                         5355.0],
#                'Jain Fairness Index': [0.03652830188679245,
#                                        0.03636363636363636,
#                                        0.034103960396039606,
#                                        0.03576595744680851,
#                                        0.04019565217391304,
#                                        0.0316875,
#                                        0.03671176470588235,
#                                        0.034225,
#                                        0.04149019607843137,
#                                        0.03724226804123711,
#                                        0.03358139534883721,
#                                        0.03675,
#                                        0.040653153153153154,
#                                        0.03208888888888889,
#                                        0.040692307692307694,
#                                        0.03822727272727273,
#                                        0.036543478260869566,
#                                        0.04149019607843137,
#                                        0.03430612244897959,
#                                        0.043859649122807015,
#                                        0.03648989898989899],
#                'Network Energy Efficiency [bytes / joule]': [1.6446965754153084,
#                                                              1.483837848668858,
#                                                              1.5357544327254824,
#                                                              1.5258876708015752,
#                                                              1.6093351680231767,
#                                                              1.4384545512601423,
#                                                              1.4558571044683235,
#                                                              1.3599845396050612,
#                                                              1.73689514040348,
#                                                              1.5912479073699728,
#                                                              1.3936635505782597,
#                                                              1.5644117320806419,
#                                                              1.7839491357234571,
#                                                              1.3937388798293944,
#                                                              1.738297682196505,
#                                                              1.6269148687104051,
#                                                              1.5283605016971222,
#                                                              1.738733414464923,
#                                                              1.518463047353118,
#                                                              1.906735172449381,
#                                                              1.5818953878947584],
#                'Overhead': [15851.0,
#                             15708.0,
#                             15945.0,
#                             15859.0,
#                             15734.0,
#                             15833.0,
#                             15902.0,
#                             15727.0,
#                             15772.0,
#                             15701.0,
#                             15952.0,
#                             15748.0,
#                             15795.0,
#                             15946.0,
#                             15685.0,
#                             15800.0,
#                             15682.0,
#                             15658.0,
#                             15867.0,
#                             15684.0,
#                             15817.0],
#                'Satellite Energy Efficiency [bytes / joule]': [192.1444936899594,
#                                                                173.71025461249167,
#                                                                179.87493859845682,
#                                                                178.77918781725617,
#                                                                188.02244774734172,
#                                                                168.6823334621699,
#                                                                170.73481021150246,
#                                                                159.59219935733384,
#                                                                202.53281088011198,
#                                                                185.95739058030952,
#                                                                163.6949286372332,
#                                                                182.9018023664793,
#                                                                207.6007215679765,
#                                                                163.6949286372332,
#                                                                202.53281088011198,
#                                                                190.08481369808172,
#                                                                178.77918781725617,
#                                                                202.53281088011198,
#                                                                177.82270191379575,
#                                                                221.38634223183692,
#                                                                184.95909654905117],
#                'Throughput [bytes / hour]': [49896.0,
#                                              45360.0,
#                                              47061.0,
#                                              46494.0,
#                                              48762.0,
#                                              44226.0,
#                                              44793.0,
#                                              41958.0,
#                                              52164.0,
#                                              48195.0,
#                                              43092.0,
#                                              47628.0,
#                                              53864.99999999999,
#                                              43092.0,
#                                              52164.0,
#                                              49329.0,
#                                              46494.0,
#                                              52164.0,
#                                              46494.0,
#                                              56699.99999999999,
#                                              48195.0]},
#         3000: {'Average Delay [seconds]': [],
#                'Average Energy Efficiency per Node [bytes / joule]': [0.5650537784556555,
#                                                                       0.5618427226603938,
#                                                                       0.5432020074589513,
#                                                                       0.6284552821199642,
#                                                                       0.6029559956862347,
#                                                                       0.5532248302311747,
#                                                                       0.5622597714638052,
#                                                                       0.6018444854098516,
#                                                                       0.6951359723289681,
#                                                                       0.6140184422993477,
#                                                                       0.5934234861784269,
#                                                                       0.6257495965740899,
#                                                                       0.6208668853336211,
#                                                                       0.6552083200188155,
#                                                                       0.6264035367951484,
#                                                                       0.538331605259848,
#                                                                       0.5762253260179111,
#                                                                       0.5552807237167854,
#                                                                       0.6413208517738196,
#                                                                       0.526756488792552,
#                                                                       0.5767550766057292],
#                'Data': [3024.0,
#                         3024.0,
#                         2898.0,
#                         3339.0,
#                         3213.0,
#                         2961.0,
#                         3024.0,
#                         3213.0,
#                         3654.0,
#                         3276.0,
#                         3150.0,
#                         3339.0,
#                         3276.0,
#                         3465.0,
#                         3339.0,
#                         2898.0,
#                         3087.0,
#                         2961.0,
#                         3402.0,
# ...
#                                              0.017,
#                                              0.018512820512820514,
#                                              0.02154255319148936,
#                                              0.01626449275362319,
#                                              0.02,
#                                              0.02075,
#                                              0.01975,
#                                              0.0185,
#                                              0.017513513513513514],
#                      'Network Energy Efficiency [bytes / joule]': [0.25871631167799586,
#                                                                    0.2521710309847507,
#                                                                    0.29887123333828997,
#                                                                    0.24743028035602183,
#                                                                    0.23417130801289696,
#                                                                    0.2894937596127406,
#                                                                    0.24582164687966324,
#                                                                    0.2750429268559558,
#                                                                    0.2820658464592285,
#                                                                    0.28349337947239617,
#                                                                    0.25232861873946333,
#                                                                    0.2683191942868822,
#                                                                    0.23770893196399387,
#                                                                    0.2712813895187779,
#                                                                    0.3284826503367089,
#                                                                    0.23246031662948335,
#                                                                    0.2861282141294831,
#                                                                    0.2997543169018578,
#                                                                    0.2811043467744934,
#                                                                    0.2639612413497505,
#                                                                    0.25187851861539357],
#                      'Overhead': [489992.0,
#                                   496838.0,
#                                   475934.0,
#                                   497844.0,
#                                   496240.0,
#                                   486982.0,
#                                   495330.0,
#                                   485451.0,
#                                   485720.0,
#                                   482849.0,
#                                   496453.0,
#                                   484633.0,
#                                   496082.0,
#                                   485892.0,
#                                   475052.0,
#                                   500483.0,
#                                   484697.0,
#                                   481026.0,
#                                   489550.0,
#                                   486292.0,
#                                   497502.0],
#                      'Satellite Energy Efficiency [bytes / joule]': [238.64847234434103,
#                                                                      235.60902846047284,
#                                                                      271.2899604923924,
#                                                                      227.85146813434005,
#                                                                      215.841081285158,
#                                                                      268.2462206819064,
#                                                                      229.51230821540398,
#                                                                      250.74721039183208,
#                                                                      256.76139726948645,
#                                                                      256.76139726948645,
#                                                                      235.60902846047284,
#                                                                      244.70961439679672,
#                                                                      218.85232406988843,
#                                                                      247.73134706777873,
#                                                                      295.4253412776622,
#                                                                      215.841081285158,
#                                                                      259.75975479297745,
#                                                                      274.32769980274185,
#                                                                      262.14066830240347,
#                                                                      241.68199522818114,
#                                                                      235.60902846047284],
#                      'Throughput [bytes / hour]': [41391.0,
#                                                    40824.0,
#                                                    46494.0,
#                                                    40257.0,
#                                                    37989.0,
#                                                    45927.0,
#                                                    39690.0,
#                                                    43659.0,
#                                                    44793.0,
#                                                    44793.0,
#                                                    40824.0,
#                                                    42525.0,
#                                                    38556.0,
#                                                    43092.0,
#                                                    51030.0,
#                                                    37989.0,
#                                                    45360.0,
#                                                    47061.0,
#                                                    44793.0,
#                                                    41958.0,
#                                                    40824.0]},
#               5000: {'Average Delay [seconds]': [],
#                      'Average Energy Efficiency per Node [bytes / joule]': [0.18022598780888774,
#                                                                             0.21516140002520392,
#                                                                             0.20459248843119943,
#                                                                             0.19487281520374813,
#                                                                             0.17856823441451503,
#                                                                             0.20035320560301023,
#                                                                             0.21414018250793518,
#                                                                             0.1814224708720303,
#                                                                             0.17001836391931027,
#                                                                             0.18172894482644836,
#                                                                             0.18116315164302624,
#                                                                             0.1791952642531688,
#                                                                             0.19089652964971687,
#                                                                             0.19834834791858796,
#                                                                             0.19007321732289856,
#                                                                             0.19574736574871937,
#                                                                             0.14268660187179907,
#                                                                             0.1692015371536383,
#                                                                             0.18151056957960962,
#                                                                             0.21401771146428555],
#                      'Data': [4095.0,
#                               4725.0,
#                               4536.0,
#                               4410.0,
#                               4032.0,
#                               4473.0,
#                               4725.0,
#                               4095.0,
#                               3906.0,
#                               4095.0,
#                               4095.0,
#                               4032.0,
#                               4284.0,
#                               4473.0,
#                               4284.0,
#                               4410.0,
#                               3339.0,
#                               3906.0,
#                               4095.0,
#                               4725.0],
#                      'Jain Fairness Index': [0.013,
#                                              0.01461038961038961,
#                                              0.013642105263157895,
#                                              0.014,
#                                              0.0128,
#                                              0.01381095890410959,
#                                              0.014240506329113924,
#                                              0.012611940298507462,
#                                              0.0120125,
#                                              0.013,
#                                              0.013,
#                                              0.0128,
#                                              0.012844444444444445,
#                                              0.01381095890410959,
#                                              0.0136,
#                                              0.014,
#                                              0.0106,
#                                              0.0124,
#                                              0.012611940298507462,
#                                              0.015],
#                      'Network Energy Efficiency [bytes / joule]': [0.18007130076475011,
#                                                                    0.21497238514130665,
#                                                                    0.20441498347557374,
#                                                                    0.19470407486356103,
#                                                                    0.17841415640388605,
#                                                                    0.20018075021002105,
#                                                                    0.2139529568227692,
#                                                                    0.18126572403283683,
#                                                                    0.16987445702017379,
#                                                                    0.18157166818985568,
#                                                                    0.1810068523879705,
#                                                                    0.17904010274458287,
#                                                                    0.1907301630078616,
#                                                                    0.19817583268604405,
#                                                                    0.18990828200265503,
#                                                                    0.19557710812529924,
#                                                                    0.1425642175643099,
#                                                                    0.16905609863499482,
#                                                                    0.18135367053682777,
#                                                                    0.2138306997805777],
#                      'Overhead': [627204.0,
#                                   604902.0,
#                                   611747.0,
#                                   624251.0,
#                                   622662.0,
#                                   616743.0,
#                                   608286.0,
#                                   622362.0,
#                                   635424.0,
#                                   621165.0,
#                                   623439.0,
#                                   620142.0,
#                                   618173.0,
#                                   621681.0,
#                                   621292.0,
#                                   620962.0,
#                                   644628.0,
#                                   636676.0,
#                                   622063.0,
#                                   608694.0],
#                      'Satellite Energy Efficiency [bytes / joule]': [209.80120369667773,
#                                                                      244.70961439679672,
#                                                                      235.60902846047284,
#                                                                      224.8575009285211,
#                                                                      206.77253537700082,
#                                                                      232.5636462242323,
#                                                                      244.70961439679672,
#                                                                      209.80120369667773,
#                                                                      200.69765541160987,
#                                                                      209.80120369667773,
#                                                                      209.80120369667773,
#                                                                      206.77253537700082,
#                                                                      218.85232406988843,
#                                                                      227.85146813434005,
#                                                                      218.85232406988843,
#                                                                      224.8575009285211,
#                                                                      166.21415089972712,
#                                                                      196.67796413926945,
#                                                                      209.80120369667773,
#                                                                      244.70961439679672],
#                      'Throughput [bytes / hour]': [36855.0,
#                                                    42525.0,
#                                                    40824.0,
#                                                    39690.0,
#                                                    36288.0,
#                                                    40257.0,
#                                                    42525.0,
#                                                    36855.0,
#                                                    35154.0,
#                                                    36855.0,
#                                                    36855.0,
#                                                    36288.0,
#                                                    38556.0,
#                                                    40257.0,
#                                                    38556.0,
#                                                    39690.0,
#                                                    30050.999999999996,
#                                                    35154.0,
#                                                    36855.0,
#                                                    42525.0]}}}

# %%
output_dir = "output_graphs"

def plot_runs(metric_names, label, ylims, is_log=False, show_metric_name=False):
    for metric in metric_names:
        for key in dfs:
            x = metrics[key].keys()
            ys = [metrics[key][node_count][metric] for node_count in x]
            y = [np.average(y) for y in ys]
            yerr = [np.std(y) for y in ys]

            key_label = key if not show_metric_name else f"{metric} - {key}"
            plt.errorbar(x, y, yerr=yerr, label=key_label, capsize=4, clip_on=False)
    
    plt.ylabel(label)
    plt.xlabel("Number of nodes")
    plt.legend(loc="lower left")
    plt.grid(linestyle='-', color='0.95')
    
    if is_log:
        plt.yscale("log")  
    
    plt.ylim(ylims[0], ylims[1])
    plt.xlim(10, 5000)

    plt.savefig(os.path.join(output_dir, f"{label.replace(' ', '_').replace('/', '_')}.png"))
    plt.show()

##### Satellite Energy Efficiency [bytes / joule]
metric = "Satellite Energy Efficiency [bytes / joule]"
plot_runs([metric], metric, [0, 400], False)

##### Average Energy Efficiency per Node [bytes / joule]
metric = "Average Energy Efficiency per Node [bytes / joule]"
plot_runs([metric], metric, [0.1, 100], True)

##### Network Energy Efficiency [bytes / joule]
metric = "Network Energy Efficiency [bytes / joule]"
plot_runs([metric], metric, [0.1, 100], True)

##### Jain Fairness Index
metric = "Jain Fairness Index"
plot_runs([metric], metric, [0.001, 1], True)

##### Throughput bytes / hour
metric = "Throughput [bytes / hour]"
plot_runs([metric], metric, [10000, 100000])

##### Overhead and data [bytes]
plot_runs(["Overhead", "Data"], "Overhead and data [bytes]", [100, 1000000], True, True)

##### Average Delay [seconds]
metric = "Average Delay [seconds]"
plot_runs([metric], metric, [0, 400])
# Out:
# /home/jason/Code/thesis-playground/ress-iot-vs-dqrap-paper/venv/lib/python3.8/site-packages/numpy/lib/function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# /home/jason/Code/thesis-playground/ress-iot-vs-dqrap-paper/venv/lib/python3.8/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/jason/Code/thesis-playground/ress-iot-vs-dqrap-paper/venv/lib/python3.8/site-packages/numpy/core/_methods.py:269: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/jason/Code/thesis-playground/ress-iot-vs-dqrap-paper/venv/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/jason/Code/thesis-playground/ress-iot-vs-dqrap-paper/venv/lib/python3.8/site-packages/numpy/core/_methods.py:261: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/jason/Code/thesis-playground/ress-iot-vs-dqrap-paper/venv/lib/python3.8/site-packages/matplotlib/axes/_axes.py:1185: RuntimeWarning: All-NaN axis encountered
#   miny = np.nanmin(masked_verts[..., 1])
# /home/jason/Code/thesis-playground/ress-iot-vs-dqrap-paper/venv/lib/python3.8/site-packages/matplotlib/axes/_axes.py:1186: RuntimeWarning: All-NaN axis encountered
#   maxy = np.nanmax(masked_verts[..., 1])
