# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pprint

# %%
import os

results_path = "/home/jason/Applications/omnetpp-6.0.1/samples/florasat/simulations/dtsiot/results"
data_dir = "data"

rebuild_csv = True
if rebuild_csv:
    sca_files = [f for f in os.listdir(results_path) if f.endswith(".sca")]
    # vec_files = [f for f in os.listdir(results_path) if f.endswith(".vec")]

    for file_name in sca_files:
        print(file_name)
        os.system(f"opp_scavetool x {os.path.join(results_path, file_name)} -o {os.path.join(data_dir, file_name)}.csv")


sca_files = [f for f in os.listdir(data_dir) if ".sca" in f]
# vec_files = [f for f in os.listdir(data_dir) if ".vec" in f]

dfs = {
    "RESS-IoT": {
        "SCA": {},
        "VEC": {},
    },
    "DQ": {
        "SCA": {},
        "VEC": {},
    },
}

for file_name in sca_files:
    print(file_name)
    df = pd.read_csv(f"{os.path.join(data_dir, file_name)}", dtype=str)
    
    if ".sca" in file_name:
        numNodes = int(df.loc[df['name'] == 'nrOfNodes'].value.iloc[0])
        file_type = "SCA"
    elif ".vec" in file_name:
        numNodes = int(df.loc[df['attrname'] == "**.nrOfNodes"].attrvalue.iloc[0])
        file_type = "VEC"
    
    if "RESS-IoT" in file_name:
        protocol = "RESS-IoT"
    elif "DQ" in file_name:
        protocol = "DQ"
    
    try:
        dfs[protocol][file_type][numNodes].append(df)
    except KeyError:
        dfs[protocol][file_type][numNodes] = [df]

for protocol in dfs:
    node_counts = list(dfs[protocol]["SCA"].keys())
    node_counts.sort()
    
    dfs[protocol]["SCA"] = {node_count: dfs[protocol]["SCA"][node_count] for node_count in node_counts}
    # dfs[protocol]["VEC"] = {node_count: dfs[protocol]["VEC"][node_count] for node_count in node_counts}

pd.set_option('display.max_rows', None)   

df = None
# Out:
# DQ-N=500-#17.sca
# Exported 3165 scalars, 67200 parameters
# DQ-N=3000-#14.sca
# Exported 18105 scalars, 394700 parameters
# DQ-N=1000-#11.sca
# Exported 6164 scalars, 132700 parameters
# DQ-N=10-#16.sca
# Exported 80 scalars, 3010 parameters
# DQ-N=500-#12.sca
# Exported 3161 scalars, 67200 parameters
# DQ-N=10-#18.sca
# Exported 80 scalars, 3010 parameters
# DQ-N=10-#19.sca
# Exported 80 scalars, 3010 parameters
# DQ-N=5000-#3.sca
# Exported 30085 scalars, 656700 parameters
# DQ-N=500-#3.sca
# Exported 3156 scalars, 67200 parameters
# DQ-N=1000-#1.sca
# Exported 6170 scalars, 132700 parameters
# DQ-N=500-#15.sca
# Exported 3165 scalars, 67200 parameters
# DQ-N=4000-#10.sca
# Exported 24103 scalars, 525700 parameters
# DQ-N=1000-#14.sca
# Exported 6167 scalars, 132700 parameters
# DQ-N=500-#2.sca
# Exported 3163 scalars, 67200 parameters
# DQ-N=5000-#9.sca
# Exported 30090 scalars, 656700 parameters
# DQ-N=2000-#2.sca
# Exported 12131 scalars, 263700 parameters
# DQ-N=2000-#20.sca
# Exported 12133 scalars, 263700 parameters
# DQ-N=4000-#17.sca
# Exported 24097 scalars, 525700 parameters
# DQ-N=1000-#9.sca
# Exported 6171 scalars, 132700 parameters
# DQ-N=500-#8.sca
# Exported 3159 scalars, 67200 parameters
# DQ-N=2000-#10.sca
# Exported 12135 scalars, 263700 parameters
# DQ-N=4000-#1.sca
# Exported 24087 scalars, 525700 parameters
# DQ-N=3000-#4.sca
# Exported 18096 scalars, 394700 parameters
# DQ-N=100-#3.sca
# Exported 708 scalars, 14800 parameters
# DQ-N=500-#18.sca
# Exported 3161 scalars, 67200 parameters
# DQ-N=10-#8.sca
# Exported 80 scalars, 3010 parameters
# DQ-N=3000-#10.sca
# Exported 18102 scalars, 394700 parameters
# DQ-N=100-#9.sca
# Exported 710 scalars, 14800 parameters
# DQ-N=2000-#15.sca
# Exported 12133 scalars, 263700 parameters
# DQ-N=5000-#15.sca
# Exported 30083 scalars, 656700 parameters
# DQ-N=10-#6.sca
# Exported 80 scalars, 3010 parameters
# DQ-N=1000-#15.sca
# Exported 6162 scalars, 132700 parameters
# DQ-N=3000-#20.sca
# Exported 18102 scalars, 394700 parameters
# DQ-N=10-#17.sca
# Exported 80 scalars, 3010 parameters
# DQ-N=10-#14.sca
# Exported 80 scalars, 3010 parameters
# DQ-N=2000-#3.sca
# Exported 12119 scalars, 263700 parameters
# DQ-N=10-#13.sca
# Exported 80 scalars, 3010 parameters
# DQ-N=2000-#9.sca
# Exported 12135 scalars, 263700 parameters
# DQ-N=4000-#19.sca
# Exported 24089 scalars, 525700 parameters
# DQ-N=5000-#1.sca
# Exported 30085 scalars, 656700 parameters
# DQ-N=100-#11.sca
# Exported 709 scalars, 14800 parameters
# DQ-N=3000-#12.sca
# Exported 18105 scalars, 394700 parameters
# DQ-N=1000-#13.sca
# Exported 6165 scalars, 132700 parameters
# DQ-N=1000-#17.sca
# Exported 6171 scalars, 132700 parameters
# DQ-N=10-#2.sca
# Exported 80 scalars, 3010 parameters
# DQ-N=5000-#17.sca
# Exported 30084 scalars, 656700 parameters
# DQ-N=100-#13.sca
# Exported 708 scalars, 14800 parameters
# DQ-N=500-#19.sca
# Exported 3160 scalars, 67200 parameters
# DQ-N=3000-#2.sca
# Exported 18102 scalars, 394700 parameters
# DQ-N=4000-#20.sca
# Exported 24094 scalars, 525700 parameters
# DQ-N=3000-#11.sca
# Exported 18100 scalars, 394700 parameters
# DQ-N=2000-#4.sca
# Exported 12127 scalars, 263700 parameters
# DQ-N=4000-#15.sca
# Exported 24092 scalars, 525700 parameters
# DQ-N=10-#5.sca
# Exported 80 scalars, 3010 parameters
# DQ-N=100-#4.sca
# Exported 704 scalars, 14800 parameters
# DQ-N=1000-#0.sca
# Exported 6169 scalars, 132700 parameters
# DQ-N=4000-#9.sca
# Exported 24086 scalars, 525700 parameters
# DQ-N=4000-#14.sca
# Exported 24087 scalars, 525700 parameters
# DQ-N=5000-#20.sca
# Exported 30084 scalars, 656700 parameters
# DQ-N=2000-#5.sca
# Exported 12146 scalars, 263700 parameters
# DQ-N=1000-#3.sca
# Exported 6169 scalars, 132700 parameters
# DQ-N=10-#10.sca
# Exported 80 scalars, 3010 parameters
# DQ-N=100-#6.sca
# Exported 709 scalars, 14800 parameters
# DQ-N=100-#2.sca
# Exported 710 scalars, 14800 parameters
# DQ-N=3000-#3.sca
# Exported 18103 scalars, 394700 parameters
# DQ-N=5000-#18.sca
# Exported 30081 scalars, 656700 parameters
# DQ-N=3000-#8.sca
# Exported 18101 scalars, 394700 parameters
# DQ-N=1000-#10.sca
# Exported 6168 scalars, 132700 parameters
# DQ-N=2000-#17.sca
# Exported 12144 scalars, 263700 parameters
# DQ-N=2000-#13.sca
# Exported 12130 scalars, 263700 parameters
# DQ-N=4000-#5.sca
# Exported 24092 scalars, 525700 parameters
# DQ-N=100-#5.sca
# Exported 710 scalars, 14800 parameters
# DQ-N=100-#10.sca
# Exported 710 scalars, 14800 parameters
# DQ-N=3000-#6.sca
# Exported 18097 scalars, 394700 parameters
# DQ-N=5000-#5.sca
# Exported 30084 scalars, 656700 parameters
# DQ-N=10-#20.sca
# Exported 80 scalars, 3010 parameters
# DQ-N=4000-#0.sca
# Exported 24091 scalars, 525700 parameters
# DQ-N=100-#1.sca
# Exported 709 scalars, 14800 parameters
# DQ-N=1000-#5.sca
# Exported 6171 scalars, 132700 parameters
# DQ-N=10-#15.sca
# Exported 80 scalars, 3010 parameters
# DQ-N=500-#1.sca
# Exported 3167 scalars, 67200 parameters
# DQ-N=100-#12.sca
# Exported 709 scalars, 14800 parameters
# DQ-N=2000-#0.sca
# Exported 12124 scalars, 263700 parameters
# DQ-N=100-#0.sca
# Exported 710 scalars, 14800 parameters
# DQ-N=100-#7.sca
# Exported 710 scalars, 14800 parameters
# DQ-N=10-#7.sca
# Exported 80 scalars, 3010 parameters
# DQ-N=500-#9.sca
# Exported 3158 scalars, 67200 parameters
# DQ-N=500-#6.sca
# Exported 3150 scalars, 67200 parameters
# DQ-N=2000-#14.sca
# Exported 12130 scalars, 263700 parameters
# DQ-N=2000-#19.sca
# Exported 12129 scalars, 263700 parameters
# DQ-N=100-#17.sca
# Exported 708 scalars, 14800 parameters
# DQ-N=100-#18.sca
# Exported 708 scalars, 14800 parameters
# DQ-N=4000-#11.sca
# Exported 24086 scalars, 525700 parameters
# DQ-N=5000-#10.sca
# Exported 30086 scalars, 656700 parameters
# DQ-N=500-#11.sca
# Exported 3163 scalars, 67200 parameters
# DQ-N=10-#1.sca
# Exported 80 scalars, 3010 parameters
# DQ-N=1000-#7.sca
# Exported 6162 scalars, 132700 parameters
# DQ-N=4000-#18.sca
# Exported 24088 scalars, 525700 parameters
# DQ-N=100-#16.sca
# Exported 709 scalars, 14800 parameters
# DQ-N=3000-#1.sca
# Exported 18100 scalars, 394700 parameters
# DQ-N=10-#4.sca
# Exported 80 scalars, 3010 parameters
# DQ-N=10-#12.sca
# Exported 80 scalars, 3010 parameters
# DQ-N=500-#0.sca
# Exported 3169 scalars, 67200 parameters
# DQ-N=4000-#12.sca
# Exported 24083 scalars, 525700 parameters
# DQ-N=1000-#18.sca
# Exported 6163 scalars, 132700 parameters
# DQ-N=4000-#7.sca
# Exported 24091 scalars, 525700 parameters
# DQ-N=4000-#4.sca
# Exported 24081 scalars, 525700 parameters
# DQ-N=1000-#20.sca
# Exported 6162 scalars, 132700 parameters
# DQ-N=3000-#17.sca
# Exported 18105 scalars, 394700 parameters
# DQ-N=5000-#2.sca
# Exported 30091 scalars, 656700 parameters
# DQ-N=1000-#4.sca
# Exported 6168 scalars, 132700 parameters
# DQ-N=10-#9.sca
# Exported 80 scalars, 3010 parameters
# DQ-N=100-#14.sca
# Exported 706 scalars, 14800 parameters
# DQ-N=1000-#16.sca
# Exported 6168 scalars, 132700 parameters
# DQ-N=2000-#8.sca
# Exported 12143 scalars, 263700 parameters
# DQ-N=2000-#16.sca
# Exported 12142 scalars, 263700 parameters
# DQ-N=4000-#16.sca
# Exported 24088 scalars, 525700 parameters
# DQ-N=3000-#9.sca
# Exported 18099 scalars, 394700 parameters
# DQ-N=100-#15.sca
# Exported 710 scalars, 14800 parameters
# DQ-N=2000-#18.sca
# Exported 12135 scalars, 263700 parameters
# DQ-N=2000-#7.sca
# Exported 12132 scalars, 263700 parameters
# DQ-N=500-#4.sca
# Exported 3162 scalars, 67200 parameters
# DQ-N=2000-#6.sca
# Exported 12149 scalars, 263700 parameters
# DQ-N=100-#20.sca
# Exported 705 scalars, 14800 parameters
# DQ-N=3000-#15.sca
# Exported 18106 scalars, 394700 parameters
# DQ-N=2000-#1.sca
# Exported 12122 scalars, 263700 parameters
# DQ-N=4000-#2.sca
# Exported 24090 scalars, 525700 parameters
# DQ-N=3000-#0.sca
# Exported 18093 scalars, 394700 parameters
# DQ-N=3000-#5.sca
# Exported 18097 scalars, 394700 parameters
# DQ-N=500-#7.sca
# Exported 3161 scalars, 67200 parameters
# DQ-N=500-#13.sca
# Exported 3170 scalars, 67200 parameters
# DQ-N=2000-#12.sca
# Exported 12137 scalars, 263700 parameters
# DQ-N=4000-#3.sca
# Exported 24085 scalars, 525700 parameters
# DQ-N=5000-#12.sca
# Exported 30087 scalars, 656700 parameters
# DQ-N=3000-#18.sca
# Exported 18095 scalars, 394700 parameters
# DQ-N=1000-#8.sca
# Exported 6162 scalars, 132700 parameters
# DQ-N=5000-#19.sca
# Exported 30081 scalars, 656700 parameters
# DQ-N=500-#5.sca
# Exported 3157 scalars, 67200 parameters
# DQ-N=5000-#7.sca
# Exported 30090 scalars, 656700 parameters
# DQ-N=4000-#6.sca
# Exported 24089 scalars, 525700 parameters
# DQ-N=2000-#11.sca
# Exported 12133 scalars, 263700 parameters
# DQ-N=4000-#8.sca
# Exported 24087 scalars, 525700 parameters
# DQ-N=500-#16.sca
# Exported 3165 scalars, 67200 parameters
# DQ-N=1000-#12.sca
# Exported 6159 scalars, 132700 parameters
# DQ-N=5000-#13.sca
# Exported 30088 scalars, 656700 parameters
# DQ-N=5000-#0.sca
# Exported 30087 scalars, 656700 parameters
# DQ-N=5000-#8.sca
# Exported 30081 scalars, 656700 parameters
# DQ-N=500-#14.sca
# Exported 3171 scalars, 67200 parameters
# DQ-N=500-#20.sca
# Exported 3157 scalars, 67200 parameters
# DQ-N=10-#3.sca
# Exported 80 scalars, 3010 parameters
# DQ-N=5000-#11.sca
# Exported 30089 scalars, 656700 parameters
# DQ-N=1000-#2.sca
# Exported 6160 scalars, 132700 parameters
# DQ-N=3000-#7.sca
# Exported 18096 scalars, 394700 parameters
# DQ-N=5000-#16.sca
# Exported 30084 scalars, 656700 parameters
# DQ-N=1000-#19.sca
# Exported 6165 scalars, 132700 parameters
# DQ-N=5000-#14.sca
# Exported 30087 scalars, 656700 parameters
# DQ-N=10-#11.sca
# Exported 80 scalars, 3010 parameters
# DQ-N=100-#19.sca
# Exported 708 scalars, 14800 parameters
# DQ-N=100-#8.sca
# Exported 710 scalars, 14800 parameters
# DQ-N=5000-#6.sca
# Exported 30085 scalars, 656700 parameters
# DQ-N=1000-#6.sca
# Exported 6164 scalars, 132700 parameters
# DQ-N=10-#0.sca
# Exported 80 scalars, 3010 parameters
# DQ-N=5000-#4.sca
# Exported 30088 scalars, 656700 parameters
# DQ-N=3000-#16.sca
# Exported 18090 scalars, 394700 parameters
# DQ-N=3000-#19.sca
# Exported 18109 scalars, 394700 parameters
# DQ-N=3000-#13.sca
# Exported 18099 scalars, 394700 parameters
# DQ-N=4000-#13.sca
# Exported 24090 scalars, 525700 parameters
# DQ-N=500-#10.sca
# Exported 3163 scalars, 67200 parameters
# DQ-N=100-#2.sca.csv
# RESS-IoT-N=500-#2.sca.csv
# RESS-IoT-N=10-#17.sca.csv
# DQ-N=100-#13.sca.csv
# DQ-N=500-#13.sca.csv
# DQ-N=2000-#9.sca.csv
# RESS-IoT-N=5000-#8.sca.csv
# RESS-IoT-N=500-#0.sca.csv
# DQ-N=1000-#3.sca.csv
# RESS-IoT-N=2000-#17.sca.csv
# RESS-IoT-N=500-#6.sca.csv
# DQ-N=5000-#9.sca.csv
# DQ-N=3000-#6.sca.csv
# RESS-IoT-N=4000-#15.sca.csv
# RESS-IoT-N=3000-#6.sca.csv
# DQ-N=100-#7.sca.csv
# RESS-IoT-N=3000-#5.sca.csv
# DQ-N=500-#20.sca.csv
# DQ-N=5000-#16.sca.csv
# RESS-IoT-N=100-#15.sca.csv
# DQ-N=1000-#0.sca.csv
# RESS-IoT-N=4000-#9.sca.csv
# DQ-N=5000-#0.sca.csv
# RESS-IoT-N=5000-#13.sca.csv
# RESS-IoT-N=4000-#4.sca.csv
# RESS-IoT-N=500-#1.sca.csv
# RESS-IoT-N=100-#8.sca.csv
# DQ-N=4000-#0.sca.csv
# DQ-N=4000-#10.sca.csv
# RESS-IoT-N=500-#19.sca.csv
# DQ-N=1000-#6.sca.csv
# RESS-IoT-N=1000-#7.sca.csv
# DQ-N=100-#1.sca.csv
# RESS-IoT-N=3000-#15.sca.csv
# DQ-N=100-#3.sca.csv
# RESS-IoT-N=4000-#12.sca.csv
# RESS-IoT-N=4000-#0.sca.csv
# RESS-IoT-N=500-#4.sca.csv
# DQ-N=2000-#4.sca.csv
# DQ-N=3000-#5.sca.csv
# DQ-N=4000-#11.sca.csv
# RESS-IoT-N=1000-#9.sca.csv
# RESS-IoT-N=500-#10.sca.csv
# DQ-N=100-#14.sca.csv
# RESS-IoT-N=5000-#3.sca.csv
# RESS-IoT-N=10-#4.sca.csv
# DQ-N=5000-#10.sca.csv
# RESS-IoT-N=5000-#7.sca.csv
# DQ-N=4000-#1.sca.csv
# DQ-N=3000-#14.sca.csv
# RESS-IoT-N=3000-#0.sca.csv
# RESS-IoT-N=4000-#17.sca.csv
# DQ-N=2000-#12.sca.csv
# DQ-N=1000-#16.sca.csv
# DQ-N=1000-#15.sca.csv
# DQ-N=1000-#19.sca.csv
# RESS-IoT-N=100-#2.sca.csv
# DQ-N=5000-#8.sca.csv
# DQ-N=3000-#10.sca.csv
# DQ-N=100-#0.sca.csv
# DQ-N=2000-#16.sca.csv
# DQ-N=100-#12.sca.csv
# RESS-IoT-N=2000-#11.sca.csv
# RESS-IoT-N=500-#13.sca.csv
# RESS-IoT-N=5000-#17.sca.csv
# DQ-N=5000-#15.sca.csv
# DQ-N=10-#9.sca.csv
# RESS-IoT-N=4000-#3.sca.csv
# RESS-IoT-N=3000-#13.sca.csv
# DQ-N=3000-#8.sca.csv
# RESS-IoT-N=2000-#8.sca.csv
# RESS-IoT-N=3000-#1.sca.csv
# RESS-IoT-N=1000-#12.sca.csv
# RESS-IoT-N=100-#7.sca.csv
# RESS-IoT-N=3000-#9.sca.csv
# DQ-N=3000-#9.sca.csv
# RESS-IoT-N=2000-#14.sca.csv
# DQ-N=500-#5.sca.csv
# RESS-IoT-N=5000-#19.sca.csv
# RESS-IoT-N=4000-#11.sca.csv
# RESS-IoT-N=10-#9.sca.csv
# RESS-IoT-N=500-#5.sca.csv
# RESS-IoT-N=10-#12.sca.csv
# DQ-N=2000-#3.sca.csv
# RESS-IoT-N=3000-#17.sca.csv
# RESS-IoT-N=3000-#8.sca.csv
# RESS-IoT-N=5000-#18.sca.csv
# DQ-N=500-#15.sca.csv
# RESS-IoT-N=10-#13.sca.csv
# DQ-N=3000-#11.sca.csv
# RESS-IoT-N=500-#18.sca.csv
# RESS-IoT-N=10-#14.sca.csv
# RESS-IoT-N=5000-#6.sca.csv
# RESS-IoT-N=10-#10.sca.csv
# RESS-IoT-N=2000-#2.sca.csv
# RESS-IoT-N=5000-#16.sca.csv
# DQ-N=3000-#18.sca.csv
# RESS-IoT-N=2000-#7.sca.csv
# DQ-N=10-#1.sca.csv
# RESS-IoT-N=5000-#14.sca.csv
# RESS-IoT-N=4000-#7.sca.csv
# DQ-N=1000-#1.sca.csv
# RESS-IoT-N=1000-#15.sca.csv
# RESS-IoT-N=100-#13.sca.csv
# RESS-IoT-N=2000-#20.sca.csv
# RESS-IoT-N=3000-#14.sca.csv
# RESS-IoT-N=1000-#17.sca.csv
# DQ-N=100-#8.sca.csv
# RESS-IoT-N=4000-#10.sca.csv
# DQ-N=500-#2.sca.csv
# RESS-IoT-N=10-#8.sca.csv
# DQ-N=1000-#11.sca.csv
# DQ-N=5000-#17.sca.csv
# DQ-N=10-#15.sca.csv
# DQ-N=5000-#14.sca.csv
# RESS-IoT-N=4000-#8.sca.csv
# DQ-N=4000-#19.sca.csv
# RESS-IoT-N=2000-#1.sca.csv
# DQ-N=10-#5.sca.csv
# DQ-N=10-#16.sca.csv
# DQ-N=10-#2.sca.csv
# DQ-N=4000-#15.sca.csv
# DQ-N=3000-#2.sca.csv
# RESS-IoT-N=10-#0.sca.csv
# RESS-IoT-N=3000-#16.sca.csv
# RESS-IoT-N=4000-#19.sca.csv
# DQ-N=5000-#19.sca.csv
# RESS-IoT-N=100-#17.sca.csv
# DQ-N=3000-#12.sca.csv
# DQ-N=500-#1.sca.csv
# RESS-IoT-N=4000-#2.sca.csv
# RESS-IoT-N=5000-#10.sca.csv
# RESS-IoT-N=10-#3.sca.csv
# DQ-N=1000-#13.sca.csv
# RESS-IoT-N=10-#18.sca.csv
# RESS-IoT-N=1000-#11.sca.csv
# DQ-N=2000-#1.sca.csv
# DQ-N=2000-#11.sca.csv
# DQ-N=1000-#8.sca.csv
# RESS-IoT-N=3000-#11.sca.csv
# RESS-IoT-N=2000-#18.sca.csv
# DQ-N=2000-#8.sca.csv
# DQ-N=500-#8.sca.csv
# DQ-N=500-#9.sca.csv
# RESS-IoT-N=1000-#16.sca.csv
# DQ-N=500-#7.sca.csv
# DQ-N=10-#10.sca.csv
# DQ-N=1000-#17.sca.csv
# DQ-N=1000-#5.sca.csv
# RESS-IoT-N=3000-#2.sca.csv
# RESS-IoT-N=2000-#0.sca.csv
# RESS-IoT-N=500-#11.sca.csv
# DQ-N=5000-#18.sca.csv
# DQ-N=500-#4.sca.csv
# DQ-N=4000-#16.sca.csv
# RESS-IoT-N=500-#14.sca.csv
# RESS-IoT-N=3000-#3.sca.csv
# RESS-IoT-N=500-#16.sca.csv
# DQ-N=3000-#1.sca.csv
# DQ-N=10-#12.sca.csv
# RESS-IoT-N=100-#1.sca.csv
# RESS-IoT-N=1000-#3.sca.csv
# DQ-N=100-#16.sca.csv
# RESS-IoT-N=4000-#1.sca.csv
# RESS-IoT-N=4000-#20.sca.csv
# DQ-N=4000-#6.sca.csv
# DQ-N=100-#20.sca.csv
# RESS-IoT-N=10-#1.sca.csv
# DQ-N=10-#14.sca.csv
# RESS-IoT-N=5000-#0.sca.csv
# DQ-N=5000-#3.sca.csv
# RESS-IoT-N=100-#14.sca.csv
# DQ-N=500-#17.sca.csv
# RESS-IoT-N=4000-#16.sca.csv
# RESS-IoT-N=3000-#20.sca.csv
# RESS-IoT-N=10-#2.sca.csv
# RESS-IoT-N=1000-#8.sca.csv
# DQ-N=2000-#6.sca.csv
# RESS-IoT-N=100-#4.sca.csv
# DQ-N=100-#15.sca.csv
# DQ-N=4000-#14.sca.csv
# RESS-IoT-N=500-#12.sca.csv
# RESS-IoT-N=5000-#1.sca.csv
# DQ-N=5000-#2.sca.csv
# RESS-IoT-N=1000-#1.sca.csv
# DQ-N=1000-#12.sca.csv
# DQ-N=3000-#15.sca.csv
# DQ-N=3000-#0.sca.csv
# RESS-IoT-N=3000-#19.sca.csv
# RESS-IoT-N=5000-#20.sca.csv
# DQ-N=500-#6.sca.csv
# RESS-IoT-N=100-#20.sca.csv
# DQ-N=4000-#13.sca.csv
# DQ-N=500-#12.sca.csv
# DQ-N=2000-#2.sca.csv
# RESS-IoT-N=4000-#13.sca.csv
# RESS-IoT-N=4000-#6.sca.csv
# DQ-N=500-#14.sca.csv
# RESS-IoT-N=1000-#20.sca.csv
# RESS-IoT-N=2000-#13.sca.csv
# DQ-N=4000-#8.sca.csv
# DQ-N=10-#13.sca.csv
# RESS-IoT-N=500-#17.sca.csv
# RESS-IoT-N=10-#11.sca.csv
# DQ-N=5000-#11.sca.csv
# DQ-N=500-#11.sca.csv
# DQ-N=2000-#18.sca.csv
# RESS-IoT-N=100-#10.sca.csv
# DQ-N=100-#9.sca.csv
# RESS-IoT-N=1000-#5.sca.csv
# DQ-N=3000-#19.sca.csv
# DQ-N=2000-#13.sca.csv
# DQ-N=10-#4.sca.csv
# DQ-N=100-#10.sca.csv
# RESS-IoT-N=2000-#12.sca.csv
# RESS-IoT-N=500-#9.sca.csv
# DQ-N=4000-#20.sca.csv
# RESS-IoT-N=100-#9.sca.csv
# DQ-N=3000-#3.sca.csv
# RESS-IoT-N=100-#19.sca.csv
# DQ-N=3000-#17.sca.csv
# RESS-IoT-N=3000-#7.sca.csv
# RESS-IoT-N=500-#15.sca.csv
# RESS-IoT-N=3000-#10.sca.csv
# DQ-N=4000-#4.sca.csv
# DQ-N=1000-#4.sca.csv
# RESS-IoT-N=3000-#12.sca.csv
# DQ-N=5000-#5.sca.csv
# DQ-N=100-#5.sca.csv
# RESS-IoT-N=5000-#5.sca.csv
# DQ-N=2000-#20.sca.csv
# DQ-N=2000-#7.sca.csv
# RESS-IoT-N=500-#7.sca.csv
# RESS-IoT-N=4000-#14.sca.csv
# RESS-IoT-N=5000-#12.sca.csv
# DQ-N=100-#11.sca.csv
# RESS-IoT-N=10-#15.sca.csv
# RESS-IoT-N=100-#11.sca.csv
# DQ-N=4000-#12.sca.csv
# RESS-IoT-N=5000-#15.sca.csv
# RESS-IoT-N=1000-#6.sca.csv
# DQ-N=10-#0.sca.csv
# DQ-N=1000-#20.sca.csv
# DQ-N=3000-#4.sca.csv
# DQ-N=5000-#20.sca.csv
# DQ-N=1000-#14.sca.csv
# DQ-N=10-#11.sca.csv
# RESS-IoT-N=100-#3.sca.csv
# DQ-N=10-#3.sca.csv
# DQ-N=4000-#5.sca.csv
# DQ-N=5000-#1.sca.csv
# DQ-N=10-#20.sca.csv
# DQ-N=10-#17.sca.csv
# DQ-N=4000-#3.sca.csv
# DQ-N=500-#10.sca.csv
# DQ-N=5000-#7.sca.csv
# DQ-N=4000-#17.sca.csv
# DQ-N=10-#19.sca.csv
# RESS-IoT-N=100-#6.sca.csv
# DQ-N=2000-#17.sca.csv
# RESS-IoT-N=100-#16.sca.csv
# RESS-IoT-N=1000-#18.sca.csv
# RESS-IoT-N=5000-#9.sca.csv
# DQ-N=4000-#18.sca.csv
# DQ-N=4000-#9.sca.csv
# DQ-N=2000-#14.sca.csv
# DQ-N=1000-#9.sca.csv
# RESS-IoT-N=3000-#4.sca.csv
# DQ-N=2000-#10.sca.csv
# DQ-N=10-#7.sca.csv
# RESS-IoT-N=5000-#2.sca.csv
# DQ-N=100-#6.sca.csv
# RESS-IoT-N=5000-#4.sca.csv
# RESS-IoT-N=4000-#5.sca.csv
# RESS-IoT-N=1000-#2.sca.csv
# RESS-IoT-N=2000-#19.sca.csv
# DQ-N=500-#0.sca.csv
# RESS-IoT-N=2000-#10.sca.csv
# RESS-IoT-N=500-#8.sca.csv
# RESS-IoT-N=2000-#16.sca.csv
# RESS-IoT-N=2000-#4.sca.csv
# RESS-IoT-N=5000-#11.sca.csv
# DQ-N=3000-#16.sca.csv
# RESS-IoT-N=100-#18.sca.csv
# DQ-N=5000-#13.sca.csv
# DQ-N=500-#16.sca.csv
# DQ-N=2000-#15.sca.csv
# RESS-IoT-N=100-#12.sca.csv
# DQ-N=100-#17.sca.csv
# RESS-IoT-N=2000-#3.sca.csv
# RESS-IoT-N=1000-#10.sca.csv
# RESS-IoT-N=2000-#9.sca.csv
# DQ-N=1000-#7.sca.csv
# RESS-IoT-N=500-#20.sca.csv
# DQ-N=4000-#7.sca.csv
# DQ-N=4000-#2.sca.csv
# RESS-IoT-N=1000-#0.sca.csv
# DQ-N=10-#18.sca.csv
# DQ-N=10-#8.sca.csv
# RESS-IoT-N=10-#7.sca.csv
# DQ-N=5000-#12.sca.csv
# RESS-IoT-N=10-#19.sca.csv
# DQ-N=100-#18.sca.csv
# DQ-N=1000-#2.sca.csv
# DQ-N=2000-#0.sca.csv
# RESS-IoT-N=10-#20.sca.csv
# RESS-IoT-N=10-#5.sca.csv
# RESS-IoT-N=3000-#18.sca.csv
# DQ-N=3000-#20.sca.csv
# RESS-IoT-N=10-#16.sca.csv
# RESS-IoT-N=4000-#18.sca.csv
# RESS-IoT-N=1000-#14.sca.csv
# RESS-IoT-N=10-#6.sca.csv
# DQ-N=500-#18.sca.csv
# DQ-N=100-#4.sca.csv
# DQ-N=500-#19.sca.csv
# RESS-IoT-N=2000-#15.sca.csv
# DQ-N=1000-#18.sca.csv
# RESS-IoT-N=1000-#19.sca.csv
# RESS-IoT-N=2000-#6.sca.csv
# RESS-IoT-N=100-#5.sca.csv
# DQ-N=2000-#5.sca.csv
# DQ-N=1000-#10.sca.csv
# DQ-N=500-#3.sca.csv
# DQ-N=2000-#19.sca.csv
# DQ-N=10-#6.sca.csv
# DQ-N=5000-#4.sca.csv
# DQ-N=100-#19.sca.csv
# DQ-N=5000-#6.sca.csv
# RESS-IoT-N=100-#0.sca.csv
# RESS-IoT-N=2000-#5.sca.csv
# DQ-N=3000-#7.sca.csv
# DQ-N=3000-#13.sca.csv
# RESS-IoT-N=500-#3.sca.csv
# RESS-IoT-N=1000-#13.sca.csv
# RESS-IoT-N=1000-#4.sca.csv

# %%
def get_throughput_bytes_per_hour(df):
    # Throughput B / hr
    sim_time_hours = float(df.loc[df['name'] == 'simulated time'].value.iloc[0]) / 60 / 60
    bytes_per_data_packet = int(df.loc[df['name'] == 'dataPacketLenBits'].value.iloc[0]) / 8
    num_data_packets = int(df.loc[df['name'] == 'numDataPacketsReceived'].value.iloc[0])

    return (num_data_packets * bytes_per_data_packet) / sim_time_hours

def get_jfi(df):
    # Jain's Fairness Index
    num_nodes = int(df.loc[df['name'] == 'nrOfNodes'].value.iloc[0])
    denominator = num_nodes * df[df['name'].str.startswith('numDataPacketsReceivedByNodeId', na=False)].value.astype(int).pow(2).sum()
    numerator =  df[df['name'].str.startswith('numDataPacketsReceivedByNodeId', na=False)].value.astype(int).sum() ** 2.0
    jfi = numerator / denominator if denominator != 0 else 0
    return jfi

def get_overhead_bytes(df):
    # Total bytes of overhead (Beacon, RTS, VCTS) or (ARS, FBP)
    possible_keys = [
        ('numARSPacketsSent', 'arsPacketLenBits'),
        ('numFBPPacketsSent', 'fbpPacketLenBits'),
        ('numRTSPacketsSent', 'rtsPacketLenBits'),
        ('numBeaconPacketsSent', 'beaconPacketLenBits'),
        ('numVCTSPacketsSent', 'vctsPacketLenBits'),
    ]
    
    overhead_bits = 0
    for key in possible_keys:
        try:
            total_num_packets = df.loc[df['name'] == key[0]].value.astype(int).sum()
            bits_per_packet = int(df.loc[df['name'] == key[1]].value.iloc[0])
            overhead_bits += (total_num_packets * bits_per_packet)
        except IndexError:
            pass

    return overhead_bits / 8

def get_data_bytes(df):
    bits_per_data_packet = int(df.loc[df['name'] == 'dataPacketLenBits'].value.iloc[0])
    num_data_packets = int(df.loc[df['name'] == 'numDataPacketsReceived'].value.iloc[0])

    return bits_per_data_packet * num_data_packets / 8

def get_avg_delay(df_sca):
    num_data_packets = int(df_sca.loc[df_sca['name'] == 'numDataPacketsReceived'].value.iloc[0])
    total_delay = float(df_sca.loc[df_sca['name'] == 'totalPacketDelay'].value.iloc[0])
    
    return total_delay / num_data_packets

def get_energy_satellite_DQ(df_sca):
    p_rx = 25.74 / 1000 # W
    p_tx = 389.4 / 1000 # W
    
    num_rounds = int(df_sca.loc[df_sca['name'] == "numFBPPacketsSent"].value.iloc[0])
    
    # Sat always sends a FBP
    t_fbp = float(df_sca.loc[df_sca['name'] == "fbpPacketTime"].value.iloc[0])
    e_fbp = num_rounds * p_tx * t_fbp
    
    # Sat always listens for all contention slots
    t_ars = float(df_sca.loc[df_sca['name'] == "arsPacketTime"].value.iloc[0])
    n_slots = int(df_sca.loc[df_sca['name'] == "numContentionSlots"].value.iloc[0])
    e_ars = num_rounds * p_rx * t_ars * n_slots
    
    # Sat only listens when a data packet will be sent len(dtq) != 0
    t_data = float(df_sca.loc[df_sca['name'] == "dataPacketTime"].value.iloc[0])
    num_data_packets = float(df_sca.loc[df_sca['name'] == "numDataPacketsReceived"].value.iloc[0])
    e_data = num_data_packets * p_rx * t_data
    
    return e_fbp + e_ars + e_data

def get_energy_node_DQ(df_sca):
    p_rx = 25.74 / 1000 # W
    p_tx = 389.4 / 1000 # W
    
    num_rounds = int(df_sca.loc[df_sca['name'] == "numFBPPacketsSent"].value.iloc[0])
    num_nodes = int(df_sca.loc[df_sca['name'] == 'nrOfNodes'].value.iloc[0])

    # Nodes always listen for FBP
    t_fbp = float(df_sca.loc[df_sca['name'] == "fbpPacketTime"].value.iloc[0])
    e_fbp = num_nodes * num_rounds * p_rx * t_fbp
    
    # Nodes only send ARS when the constraints are met
    t_ars = float(df_sca.loc[df_sca['name'] == "arsPacketTime"].value.iloc[0])
    total_num_ars_packets_sent = df_sca.loc[df_sca['name'] == "numARSPacketsSent"].value.astype(int).sum()
    e_ars = total_num_ars_packets_sent * p_tx * t_ars
    
    # Only one or zero data packets can be sent each round
    t_data = float(df_sca.loc[df_sca['name'] == "dataPacketTime"].value.iloc[0])
    num_data_packets = float(df_sca.loc[df_sca['name'] == "numDataPacketsReceived"].value.iloc[0])
    e_data = num_data_packets * p_tx * t_data
    
    return e_fbp + e_ars + e_data

def get_energy_satellite_RESSIOT(df_sca):
    p_rx = 25.74 / 1000 # W
    p_tx = 389.4 / 1000 # W
        
    num_rounds = int(df_sca.loc[df_sca['name'] == "numBeaconPacketsSent"].value.iloc[0])

    t_beacon = float(df_sca.loc[df_sca['name'] == "beaconPacketTime"].value.iloc[0])
    w_rx = float(df_sca.loc[df_sca['name'] == "wrx"].value.iloc[0])
    e_rp_sat = num_rounds * ((p_tx * t_beacon) + (p_rx * w_rx))
    
    t_vcts = float(df_sca.loc[df_sca['name'] == "vctsPacketTime"].value.iloc[0])
    t_data = float(df_sca.loc[df_sca['name'] == "dataPacketTime"].value.iloc[0])
    num_data_packets = float(df_sca.loc[df_sca['name'] == "numDataPacketsReceived"].value.iloc[0])
    e_tp_sat = (num_rounds * p_tx * t_vcts) + (num_data_packets * p_rx * t_data)
    
    return e_rp_sat + e_tp_sat

def get_energy_node_RESSIOT(df_sca):
    p_rx = 25.74 / 1000 # W
    p_tx = 389.4 / 1000 # W
        
    num_rounds = int(df_sca.loc[df_sca['name'] == "numBeaconPacketsSent"].value.iloc[0])
    num_nodes = int(df_sca.loc[df_sca['name'] == 'nrOfNodes'].value.iloc[0])

    t_beacon = float(df_sca.loc[df_sca['name'] == "beaconPacketTime"].value.iloc[0])
    t_rts = float(df_sca.loc[df_sca['name'] == "rtsPacketTime"].value.iloc[0])
    total_num_rts_packets_sent = df_sca.loc[df_sca['name'] == "numRTSPacketsSent"].value.astype(int).sum()
    e_rp_nodes = (num_nodes * num_rounds * p_rx * t_beacon) + (total_num_rts_packets_sent * p_tx * t_rts)
    
    t_vcts = float(df_sca.loc[df_sca['name'] == "vctsPacketTime"].value.iloc[0])
    t_data = float(df_sca.loc[df_sca['name'] == "dataPacketTime"].value.iloc[0])
    num_data_packets = float(df_sca.loc[df_sca['name'] == "numDataPacketsReceived"].value.iloc[0])
    e_tp_nodes = (num_rounds * num_nodes * p_rx * t_vcts) + (num_data_packets * p_tx * t_data)

    return e_rp_nodes + e_tp_nodes

def get_avg_energy_efficiency_node(key, df_sca):
    if key == "RESS-IoT": 
        e_nodes = get_energy_node_RESSIOT(df_sca)
    elif key == "DQ":
        e_nodes = get_energy_node_DQ(df_sca)

    num_nodes = int(df_sca.loc[df_sca['name'] == 'nrOfNodes'].value.iloc[0])
    
    return (get_data_bytes(df_sca) / num_nodes ) / (e_nodes / num_nodes)
    
def get_energy_efficiency_satellite(key, df_sca):
    if key == "RESS-IoT": 
        e_sat = get_energy_satellite_RESSIOT(df_sca)
    elif key == "DQ":
        e_sat = get_energy_satellite_DQ(df_sca)
    
    return get_data_bytes(df_sca) / e_sat

def get_energy_efficiency_network(key, df_sca):
    if key == "RESS-IoT": 
        e_network = get_energy_satellite_RESSIOT(df_sca) + get_energy_node_RESSIOT(df_sca)
    elif key == "DQ":
        e_network = get_energy_satellite_DQ(df_sca) + get_energy_node_DQ(df_sca)
    
    return get_data_bytes(df_sca) / e_network

# %%
metrics = {}

for key in dfs:
    metrics[key] = {}
    
    for node_count in dfs[key]["SCA"]:
        print(key, node_count)
        
        metrics[key][node_count] = {
            "Average Delay [seconds]": [],
            "Jain Fairness Index": [],
            "Throughput [bytes / hour]": [],
            "Overhead": [],
            "Data": [],
            "Satellite Energy Efficiency [bytes / joule]": [],
            "Average Energy Efficiency per Node [bytes / joule]": [],
            "Network Energy Efficiency [bytes / joule]": [],
        }
        
        for df_sca in dfs[key]["SCA"][node_count]:            
            metrics[key][node_count]["Average Delay [seconds]"].append(get_avg_delay(df_sca))
            metrics[key][node_count]["Jain Fairness Index"].append(get_jfi(df_sca))
            metrics[key][node_count]["Throughput [bytes / hour]"].append(get_throughput_bytes_per_hour(df_sca))
            metrics[key][node_count]["Overhead"].append(get_overhead_bytes(df_sca))
            metrics[key][node_count]["Data"].append(get_data_bytes(df_sca))
            metrics[key][node_count]["Satellite Energy Efficiency [bytes / joule]"].append(get_energy_efficiency_satellite(key, df_sca))
            metrics[key][node_count]["Average Energy Efficiency per Node [bytes / joule]"].append(get_avg_energy_efficiency_node(key, df_sca))
            metrics[key][node_count]["Network Energy Efficiency [bytes / joule]"].append(get_energy_efficiency_network(key, df_sca))
    
pprint.pprint(metrics)
# Out:
# RESS-IoT 10
# RESS-IoT 100
# RESS-IoT 500
# RESS-IoT 1000
# RESS-IoT 2000
# RESS-IoT 3000
# RESS-IoT 4000
# RESS-IoT 5000
# DQ 10
# DQ 100
# DQ 500
# DQ 1000
# DQ 2000
# DQ 3000
# DQ 4000
# DQ 5000
# {'DQ': {10: {'Average Delay [seconds]': [17.34693018385306,
#                                          6.46422427026426,
#                                          6.104993816870396,
#                                          6.282603470084818,
#                                          6.190980898152063,
#                                          5.247028772315641,
#                                          6.306808728550741,
#                                          6.373691260170582,
#                                          11.936366856641667,
#                                          6.329434994764565,
#                                          11.849680227340816,
#                                          6.094563894384242,
#                                          11.285311135935485,
#                                          6.819221322810099,
#                                          5.8742977466554,
#                                          5.972711140006837,
#                                          5.976508384542528,
#                                          6.0046575545607,
#                                          6.185232690295334,
#                                          5.961451519053158,
#                                          15.873950195275675],
#              'Average Energy Efficiency per Node [bytes / joule]': [106.58694884297901,
#                                                                     112.71334949447002,
#                                                                     110.66396509638817,
#                                                                     113.00208457606924,
#                                                                     107.9718240933639,
#                                                                     100.8848018307489,
#                                                                     111.68273374174484,
#                                                                     102.19486296401325,
#                                                                     103.27337021469609,
#                                                                     105.47895153744683,
#                                                                     107.48720099997952,
#                                                                     107.83677988362669,
#                                                                     115.14454246707888,
#                                                                     106.00392814000932,
#                                                                     109.89409170856476,
#                                                                     109.613297919641,
#                                                                     105.21436474599881,
#                                                                     110.15291324013585,
#                                                                     105.5668524998483,
#                                                                     107.57168570136069,
#                                                                     114.19161641789917],
#              'Data': [6174.0,
#                       6804.0,
#                       6363.0,
#                       6930.0,
#                       6111.0,
#                       4914.0,
#                       6804.0,
#                       5418.0,
#                       6048.0,
#                       5796.0,
#                       6174.0,
#                       6237.0,
#                       7812.0,
#                       6363.0,
#                       6300.0,
#                       6174.0,
#                       5481.0,
#                       6300.0,
#                       5670.0,
#                       5985.0,
#                       6993.0],
#              'Jain Fairness Index': [0.8811009174311927,
#                                      0.9227848101265823,
#                                      0.881676750216076,
#                                      0.9029850746268657,
#                                      0.9003827751196172,
#                                      0.9246200607902736,
#                                      0.9671641791044776,
#                                      0.8640186915887851,
#                                      0.9365853658536586,
#                                      0.9004255319148936,
#                                      0.9060377358490566,
#                                      0.8727515583259128,
#                                      0.9023474178403755,
#                                      0.8726261762189906,
#                                      0.9363295880149812,
#                                      0.8892592592592593,
#                                      0.9449438202247191,
#                                      0.8787346221441125,
#                                      0.9806295399515739,
#                                      0.8804878048780488,
#                                      0.9270880361173814],
#              'Network Energy Efficiency [bytes / joule]': [65.33619020235642,
#                                                            70.35735887824822,
#                                                            67.70113482229112,
#                                                            71.02943641901209,
#                                                            65.50533172439836,
#                                                            57.0335084677456,
#                                                            69.9544007197481,
#                                                            60.16015006771099,
#                                                            63.59837735637871,
#                                                            63.11911627820064,
#                                                            65.57606701825542,
#                                                            66.0506555606207,
#                                                            75.47081073136823,
#                                                            66.02347266549644,
#                                                            67.26610226749132,
#                                                            66.36134533840355,
#                                                            61.476727994993574,
#                                                            67.16265602221479,
#                                                            62.52138442991888,
#                                                            64.75083909982042,
#                                                            71.72540032994652],
#              'Overhead': [1625.0,
#                           1605.0,
#                           1606.0,
#                           1604.0,
#                           1619.0,
#                           1634.0,
#                           1611.0,
#                           1635.0,
#                           1638.0,
#                           1627.0,
#                           1625.0,
#                           1621.0,
#                           1600.0,
#                           1628.0,
#                           1602.0,
#                           1613.0,
#                           1622.0,
#                           1611.0,
#                           1625.0,
#                           1620.0,
#                           1600.0],
#              'Satellite Energy Efficiency [bytes / joule]': [168.82077790045224,
#                                                              187.2276734737654,
#                                                              174.38506665323172,
#                                                              191.23106913763291,
#                                                              166.54848939897215,
#                                                              131.21196111253727,
#                                                              187.2276734737654,
#                                                              146.26145555534484,
#                                                              165.54555644746225,
#                                                              157.17101273526706,
#                                                              168.17936492610707,
#                                                              170.4558659185914,
#                                                              219.03792739166295,
#                                                              175.0542200913339,
#                                                              173.41064658186326,
#                                                              168.17936492610707,
#                                                              147.88715996428752,
#                                                              172.08927558377326,
#                                                              153.33056101230548,
#                                                              162.66275576846525,
#                                                              192.86953621990068],
#              'Throughput [bytes / hour]': [41160.0,
#                                            45360.0,
#                                            42420.0,
#                                            46200.0,
#                                            40740.0,
#                                            32760.0,
#                                            45360.0,
#                                            36120.0,
#                                            40320.0,
#                                            38640.0,
#                                            41160.0,
#                                            41580.0,
#                                            52080.0,
#                                            42420.0,
#                                            42000.0,
#                                            41160.0,
#                                            36540.0,
#                                            42000.0,
#                                            37800.0,
#                                            39900.0,
#                                            46620.0]},
#         100: {'Average Delay [seconds]': [206.782645597761,
#                                           201.48861497726827,
#                                           207.9661387625951,
#                                           202.67041991792684,
#                                           203.93492959174148,
#                                           204.16473759737562,
#                                           202.0529926140147,
#                                           202.47084740240885,
#                                           208.24026273781465,
#                                           200.65326347278713,
#                                           198.91505685254148,
#                                           205.9544384530439,
#                                           203.485070699703,
#                                           203.25077244499508,
#                                           205.07277955421077,
#                                           205.86051973770586,
#                                           205.87438401687317,
#                                           203.49790081718535,
#                                           199.85641617831553,
#                                           202.6487107537366,
#                                           200.93319130846828],
#               'Average Energy Efficiency per Node [bytes / joule]': [49.333106767680654,
#                                                                      48.67711122557029,
#                                                                      49.632337465281054,
#                                                                      48.813761682692245,
#                                                                      49.228355551562714,
#                                                                      49.15876819480025,
#                                                                      48.508604363945686,
#                                                                      48.27185783512999,
#                                                                      49.56160413544455,
#                                                                      47.884076095042836,
#                                                                      47.955528770664344,
#                                                                      49.50868630379073,
#                                                                      48.40831505416229,
#                                                                      48.95463393972937,
#                                                                      49.163272008844395,
#                                                                      48.59374696120109,
#                                                                      48.33880906813622,
#                                                                      48.17141526332807,
#                                                                      48.81102756986603,
#                                                                      48.59209253120005,
#                                                                      48.204801212384396],
#               'Data': [12915.0,
#                        12915.0,
#                        12915.0,
#                        12915.0,
#                        12915.0,
#                        12915.0,
#                        12852.0,
#                        12789.0,
#                        12915.0,
#                        12726.0,
#                        12915.0,
#                        12915.0,
#                        12726.0,
#                        12852.0,
#                        12852.0,
#                        12852.0,
#                        12915.0,
#                        12915.0,
#                        12978.0,
#                        12915.0,
#                        12915.0],
#               'Jain Fairness Index': [0.8960554371002132,
#                                       0.8594069529652352,
#                                       0.9076673866090713,
#                                       0.8664948453608248,
#                                       0.8629363449691991,
#                                       0.8455734406438632,
#                                       0.8854468085106383,
#                                       0.8786567164179104,
#                                       0.8664948453608248,
#                                       0.8644915254237289,
#                                       0.8066218809980806,
#                                       0.9076673866090713,
#                                       0.8718803418803419,
#                                       0.8779746835443037,
#                                       0.908646288209607,
#                                       0.8892307692307693,
#                                       0.8288954635108481,
#                                       0.8455734406438632,
#                                       0.8098473282442749,
#                                       0.8192007797270955,
#                                       0.8455734406438632],
#               'Network Energy Efficiency [bytes / joule]': [43.830939811469044,
#                                                             43.312342712837236,
#                                                             44.066986048089326,
#                                                             43.42049868300236,
#                                                             43.74823199257205,
#                                                             43.693266637055615,
#                                                             43.158360719817914,
#                                                             42.950333948258056,
#                                                             44.01121731882359,
#                                                             42.6226547735273,
#                                                             42.740113753725026,
#                                                             43.969483317403466,
#                                                             43.03751895214324,
#                                                             43.511069089019024,
#                                                             43.675809324998944,
#                                                             43.22574446552616,
#                                                             43.04429549547481,
#                                                             42.91151219726407,
#                                                             43.43890180243619,
#                                                             43.24501842097058,
#                                                             42.938003278734016],
#               'Overhead': [1829.0,
#                            1867.0,
#                            1812.0,
#                            1859.0,
#                            1835.0,
#                            1839.0,
#                            1866.0,
#                            1869.0,
#                            1816.0,
#                            1881.0,
#                            1910.0,
#                            1819.0,
#                            1850.0,
#                            1840.0,
#                            1828.0,
#                            1861.0,
#                            1887.0,
#                            1897.0,
#                            1870.0,
#                            1872.0,
#                            1895.0],
#               'Satellite Energy Efficiency [bytes / joule]': [392.9936060929349,
#                                                               392.9936060929349,
#                                                               392.9936060929349,
#                                                               392.9936060929349,
#                                                               392.9936060929349,
#                                                               392.9936060929349,
#                                                               391.3002817080879,
#                                                               389.60501886244083,
#                                                               392.9936060929349,
#                                                               387.90781422546024,
#                                                               392.9936060929349,
#                                                               392.9936060929349,
#                                                               387.90781422546024,
#                                                               391.3002817080879,
#                                                               391.3002817080879,
#                                                               391.3002817080879,
#                                                               392.9936060929349,
#                                                               392.9936060929349,
#                                                               394.68499533990297,
#                                                               392.9936060929349,
#                                                               392.9936060929349],
#               'Throughput [bytes / hour]': [86100.0,
#                                             86100.0,
#                                             86100.0,
#                                             86100.0,
#                                             86100.0,
#                                             86100.0,
#                                             85680.0,
#                                             85260.0,
#                                             86100.0,
#                                             84840.0,
#                                             86100.0,
#                                             86100.0,
#                                             84840.0,
#                                             85680.0,
#                                             85680.0,
#                                             85680.0,
#                                             86100.0,
#                                             86100.0,
#                                             86520.0,
#                                             86100.0,
#                                             86100.0]},
#         500: {'Average Delay [seconds]': [251.30256745766496,
#                                           235.8735506624579,
#                                           247.01228749443084,
#                                           247.12267573611112,
#                                           244.02520591718653,
#                                           248.35275733964582,
#                                           243.86833336028644,
#                                           247.71391955260415,
#                                           237.63155586678533,
#                                           250.20210088452083,
#                                           242.39957629839085,
#                                           246.51605329585107,
#                                           241.8407762693579,
#                                           246.24584250830614,
#                                           244.4262712424737,
#                                           250.9003506555573,
#                                           243.43380555091193,
#                                           245.99782501452358,
#                                           253.33242011408947,
#                                           247.0305631447725,
#                                           243.14659807341752],
#               'Average Energy Efficiency per Node [bytes / joule]': [12.928665524299284,
#                                                                      12.501227606319619,
#                                                                      12.336937410795194,
#                                                                      12.416569078431264,
#                                                                      12.67994615336317,
#                                                                      12.612211031286288,
#                                                                      12.586623615289115,
#                                                                      12.612211031286288,
#                                                                      12.551127696786327,
#                                                                      12.617096624570939,
#                                                                      12.953381553628475,
#                                                                      12.3417115247821,
#                                                                      12.473737297026483,
#                                                                      12.90145696013049,
#                                                                      12.465295177650866,
#                                                                      12.613432074860635,
#                                                                      12.677824121625761,
#                                                                      12.529616041564307,
#                                                                      12.476478887317315,
#                                                                      12.377349300653604,
#                                                                      12.759158200523537],
#               'Data': [12411.0,
#                        11970.0,
#                        11844.0,
#                        11907.0,
#                        12159.0,
#                        12096.0,
#                        12096.0,
#                        12096.0,
#                        12033.0,
#                        12096.0,
#                        12411.0,
#                        11844.0,
#                        11970.0,
#                        12348.0,
#                        11970.0,
#                        12096.0,
#                        12159.0,
#                        12033.0,
#                        11970.0,
#                        11907.0,
#                        12222.0],
#               'Jain Fairness Index': [0.27820071684587816,
#                                       0.2375,
#                                       0.23881081081081082,
#                                       0.2716425855513308,
#                                       0.2670179211469534,
#                                       0.26520863309352516,
#                                       0.24094117647058824,
#                                       0.2363076923076923,
#                                       0.2524636678200692,
#                                       0.256,
#                                       0.2595919732441472,
#                                       0.22512101910828025,
#                                       0.24726027397260275,
#                                       0.2783768115942029,
#                                       0.25785714285714284,
#                                       0.2614468085106383,
#                                       0.26324381625441695,
#                                       0.26340072202166065,
#                                       0.25422535211267605,
#                                       0.24892682926829268,
#                                       0.24125641025641026],
#               'Network Energy Efficiency [bytes / joule]': [12.495587682256392,
#                                                             12.083034674777373,
#                                                             11.922397313823932,
#                                                             12.000357301651915,
#                                                             12.255681138651287,
#                                                             12.18879571120426,
#                                                             12.164895862634648,
#                                                             12.18879571120426,
#                                                             12.131549025245869,
#                                                             12.193358714692435,
#                                                             12.520435592812396,
#                                                             11.926855924948178,
#                                                             12.055657163217743,
#                                                             12.470035889208042,
#                                                             12.047771287431068,
#                                                             12.189936141877169,
#                                                             12.25197653370788,
#                                                             12.109750372889598,
#                                                             12.056524022187773,
#                                                             11.962042533120623,
#                                                             12.33157155811197],
#               'Overhead': [2798.0,
#                            2793.0,
#                            2761.0,
#                            2779.0,
#                            2799.0,
#                            2771.0,
#                            2792.0,
#                            2771.0,
#                            2803.0,
#                            2767.0,
#                            2811.0,
#                            2757.0,
#                            2783.0,
#                            2803.0,
#                            2790.0,
#                            2770.0,
#                            2768.0,
#                            2788.0,
#                            2748.0,
#                            2779.0,
#                            2785.0],
#               'Satellite Energy Efficiency [bytes / joule]': [373.03056861876604,
#                                                               361.2035384897103,
#                                                               354.8169900135745,
#                                                               357.9986769110832,
#                                                               366.2837413460071,
#                                                               363.0658987425498,
#                                                               363.0658987425498,
#                                                               363.0658987425498,
#                                                               362.8988585541149,
#                                                               363.0658987425498,
#                                                               374.60097594079815,
#                                                               354.8169900135745,
#                                                               359.68965812135025,
#                                                               372.9109266079883,
#                                                               359.68965812135025,
#                                                               363.0658987425498,
#                                                               364.75116460349165,
#                                                               361.3787309889577,
#                                                               358.18841477371535,
#                                                               356.50365068985235,
#                                                               367.9733105871473],
#               'Throughput [bytes / hour]': [82740.0,
#                                             79800.0,
#                                             78960.0,
#                                             79380.0,
#                                             81060.0,
#                                             80640.0,
#                                             80640.0,
#                                             80640.0,
#                                             80220.0,
#                                             80640.0,
#                                             82740.0,
#                                             78960.0,
#                                             79800.0,
#                                             82320.0,
#                                             79800.0,
#                                             80640.0,
#                                             81060.0,
#                                             80220.0,
#                                             79800.0,
#                                             79380.0,
#                                             81480.0]},
#         1000: {'Average Delay [seconds]': [265.40818509412566,
#                                            262.02190494654945,
#                                            267.6966484731828,
#                                            261.634515449,
#                                            259.6423872732247,
#                                            266.2459671314066,
#                                            263.7041445631989,
#                                            256.6673837250055,
#                                            269.8559875179076,
#                                            264.1125998487088,
#                                            266.7581967109836,
#                                            261.9765209093656,
#                                            261.1627869607088,
#                                            263.268529589346,
#                                            262.63330907932607,
#                                            266.43708834633514,
#                                            263.3040915126175,
#                                            260.79514789048085,
#                                            260.0030642502809,
#                                            265.05631038374315,
#                                            268.0741620764162],
#                'Average Energy Efficiency per Node [bytes / joule]': [6.231140271503017,
#                                                                       6.212214906108523,
#                                                                       6.31991217758247,
#                                                                       6.2782315021660065,
#                                                                       6.0606799725811005,
#                                                                       6.196798505238204,
#                                                                       6.155356602398004,
#                                                                       6.219410390306684,
#                                                                       6.263599366537837,
#                                                                       6.190275718727941,
#                                                                       6.25104518543771,
#                                                                       6.347072185479039,
#                                                                       6.1884145868569345,
#                                                                       6.317733325375657,
#                                                                       6.288349954107269,
#                                                                       6.1896552170666865,
#                                                                       6.253563598689762,
#                                                                       6.246014439275738,
#                                                                       6.064027029153904,
#                                                                       6.2270781585371955,
#                                                                       6.296041981785245],
#                'Data': [11529.0,
#                         11466.0,
#                         11718.0,
#                         11592.0,
#                         11214.0,
#                         11466.0,
#                         11403.0,
#                         11466.0,
#                         11592.0,
#                         11466.0,
#                         11529.0,
#                         11718.0,
#                         11466.0,
#                         11655.0,
#                         11592.0,
#                         11466.0,
#                         11529.0,
#                         11529.0,
#                         11214.0,
#                         11529.0,
#                         11655.0],
#                'Jain Fairness Index': [0.14372961373390558,
#                                        0.14155555555555555,
#                                        0.13306153846153845,
#                                        0.13434920634920636,
#                                        0.1342542372881356,
#                                        0.13575409836065574,
#                                        0.14182251082251082,
#                                        0.13575409836065574,
#                                        0.1376260162601626,
#                                        0.129390625,
#                                        0.14497402597402598,
#                                        0.14415,
#                                        0.13040944881889763,
#                                        0.13744979919678715,
#                                        0.1312248062015504,
#                                        0.13575409836065574,
#                                        0.14497402597402598,
#                                        0.1313294117647059,
#                                        0.13201666666666667,
#                                        0.1334223107569721,
#                                        0.13969387755102042],
#                'Network Energy Efficiency [bytes / joule]': [6.11965987111133,
#                                                              6.101320503117388,
#                                                              6.2068928227063145,
#                                                              6.166074807689874,
#                                                              5.952549771345667,
#                                                              6.085998329589671,
#                                                              6.045487318899713,
#                                                              6.10826124317667,
#                                                              6.151504855947363,
#                                                              6.079706597143633,
#                                                              6.1393137819139785,
#                                                              6.233550573244875,
#                                                              6.077911347975613,
#                                                              6.204714402198467,
#                                                              6.175834688110895,
#                                                              6.079108062928645,
#                                                              6.141742953843229,
#                                                              6.134461198191177,
#                                                              5.955778430059967,
#                                                              6.115741761549949,
#                                                              6.183333327353605],
#                'Overhead': [3862.0,
#                             3888.0,
#                             3895.0,
#                             3889.0,
#                             3878.0,
#                             3866.0,
#                             3893.0,
#                             3865.0,
#                             3864.0,
#                             3887.0,
#                             3870.0,
#                             3881.0,
#                             3893.0,
#                             3869.0,
#                             3857.0,
#                             3889.0,
#                             3862.0,
#                             3886.0,
#                             3867.0,
#                             3875.0,
#                             3866.0],
#                'Satellite Energy Efficiency [bytes / joule]': [342.0552755175303,
#                                                                341.79104764594166,
#                                                                347.0822991173068,
#                                                                345.16036053994725,
#                                                                333.6394344299505,
#                                                                340.375862501466,
#                                                                338.6945750281691,
#                                                                341.79104764594166,
#                                                                343.73281720934693,
#                                                                340.375862501466,
#                                                                343.47664710193527,
#                                                                348.5221420094735,
#                                                                340.375862501466,
#                                                                346.84219112360734,
#                                                                345.16036053994725,
#                                                                340.375862501466,
#                                                                343.47664710193527,
#                                                                343.47664710193527,
#                                                                333.6394344299505,
#                                                                342.0552755175303,
#                                                                345.408490702923],
#                'Throughput [bytes / hour]': [76860.0,
#                                              76440.0,
#                                              78120.0,
#                                              77280.0,
#                                              74760.0,
#                                              76440.0,
#                                              76020.0,
#                                              76440.0,
#                                              77280.0,
#                                              76440.0,
#                                              76860.0,
#                                              78120.0,
#                                              76440.0,
#                                              77700.0,
#                                              77280.0,
#                                              76440.0,
#                                              76860.0,
#                                              76860.0,
#                                              74760.0,
#                                              76860.0,
#                                              77700.0]},
#         2000: {'Average Delay [seconds]': [289.53190432016555,
#                                            295.9868804727681,
#                                            294.16960781657434,
#                                            284.1981984715542,
#                                            292.7355828504461,
#                                            304.0266935985821,
#                                            298.7909554044155,
#                                            290.75209131967114,
#                                            279.43449687805696,
#                                            289.640980063,
#                                            303.9850487486857,
#                                            287.0297704836207,
#                                            288.72233253291546,
#                                            297.51889497207094,
#                                            289.6374210371226,
#                                            284.172975212461,
#                                            284.5702699900068,
#                                            296.93341044888575,
#                                            300.68833147159853,
#                                            284.03899330055197,
#                                            293.1239366822978],
#                'Average Energy Efficiency per Node [bytes / joule]': [2.392203440249108,
#                                                                       2.2561305351142535,
#                                                                       2.449124444946967,
#                                                                       2.6177376182862413,
#                                                                       2.1092140203027605,
#                                                                       2.1820259273960603,
#                                                                       2.3239707252940973,
#                                                                       2.471696582216913,
#                                                                       2.654419626590054,
#                                                                       2.338233791849783,
#                                                                       2.2845280764664055,
#                                                                       2.3841511157682436,
#                                                                       2.336249549325749,
#                                                                       2.3079978171433804,
#                                                                       2.587386554368298,
#                                                                       2.319125795017818,
#                                                                       2.436739683936625,
#                                                                       2.2964519332517184,
#                                                                       2.147351957527391,
#                                                                       2.5708241141655614,
#                                                                       2.3108965488322935],
#                'Data': [9135.0,
#                         8694.0,
#                         9324.0,
#                         9891.0,
#                         8190.0,
#                         8442.0,
#                         8946.0,
#                         9387.0,
#                         9954.0,
#                         8946.0,
#                         8820.0,
#                         9135.0,
#                         8946.0,
#                         8883.0,
#                         9765.0,
#                         8883.0,
#                         9261.0,
#                         8820.0,
#                         8316.0,
#                         9702.0,
#                         8883.0],
#                'Jain Fairness Index': [0.05446891191709845,
#                                        0.05119354838709678,
#                                        0.055877551020408166,
#                                        0.05381877729257642,
#                                        0.04592391304347826,
#                                        0.046760416666666665,
#                                        0.05306315789473684,
#                                        0.058732804232804234,
#                                        0.06118627450980392,
#                                        0.04942156862745098,
#                                        0.05764705882352941,
#                                        0.050299043062200954,
#                                        0.053627659574468085,
#                                        0.05315775401069519,
#                                        0.0603643216080402,
#                                        0.04945522388059701,
#                                        0.05270487804878049,
#                                        0.05384615384615385,
#                                        0.0484,
#                                        0.061760416666666665,
#                                        0.05097692307692308],
#                'Network Energy Efficiency [bytes / joule]': [2.3705113358170853,
#                                                              2.2356906857066607,
#                                                              2.426901751168059,
#                                                              2.593881422446753,
#                                                              2.0901802501129523,
#                                                              2.1622997003046573,
#                                                              2.302932422682088,
#                                                              2.4492027729620087,
#                                                              2.630227901316091,
#                                                              2.3170213395194676,
#                                                              2.263847650671064,
#                                                              2.3625189178619954,
#                                                              2.315072920778467,
#                                                              2.2871116502493636,
#                                                              2.5638051659213223,
#                                                              2.2981215812335813,
#                                                              2.4146036965947153,
#                                                              2.2756379421373905,
#                                                              2.127978508526027,
#                                                              2.547405064982612,
# ...
#                                                                    0.24291358206175434,
#                                                                    0.2553692290207991,
#                                                                    0.24037916448441787,
#                                                                    0.27672833584266165,
#                                                                    0.2608166902530795,
#                                                                    0.25246216269802574],
#                      'Overhead': [677257.0,
#                                   678619.0,
#                                   675849.0,
#                                   687221.0,
#                                   686861.0,
#                                   688389.0,
#                                   685640.0,
#                                   686830.0,
#                                   668125.0,
#                                   673258.0,
#                                   676223.0,
#                                   667754.0,
#                                   696983.0,
#                                   675884.0,
#                                   671149.0,
#                                   689939.0,
#                                   675017.0,
#                                   688142.0,
#                                   667885.0,
#                                   674267.0,
#                                   675943.0],
#                      'Satellite Energy Efficiency [bytes / joule]': [250.3016955503881,
#                                                                      236.3421516424887,
#                                                                      254.92712996981058,
#                                                                      221.2291219105777,
#                                                                      221.2291219105777,
#                                                                      223.5491190665946,
#                                                                      225.86568155539928,
#                                                                      236.3421516424887,
#                                                                      268.1869227211062,
#                                                                      254.92712996981058,
#                                                                      250.3016955503881,
#                                                                      261.1879677540322,
#                                                                      211.06174157643161,
#                                                                      256.50432748801427,
#                                                                      265.85746111507723,
#                                                                      238.67745867354895,
#                                                                      245.66242917666565,
#                                                                      232.79483712294046,
#                                                                      265.85746111507723,
#                                                                      250.3016955503881,
#                                                                      243.3375896034165],
#                      'Throughput [bytes / hour]': [42000.0,
#                                                    39480.0,
#                                                    42840.0,
#                                                    37380.0,
#                                                    37380.0,
#                                                    37800.0,
#                                                    38220.0,
#                                                    39480.0,
#                                                    44520.0,
#                                                    42840.0,
#                                                    42000.0,
#                                                    43260.0,
#                                                    36120.0,
#                                                    42420.0,
#                                                    44100.0,
#                                                    39900.0,
#                                                    41160.0,
#                                                    39480.0,
#                                                    44100.0,
#                                                    42000.0,
#                                                    40740.0]},
#               5000: {'Average Delay [seconds]': [234.55488241447435,
#                                                  226.64649322578023,
#                                                  210.88967339986488,
#                                                  236.2817450838734,
#                                                  247.48901837170885,
#                                                  221.4878121196413,
#                                                  210.50936309033696,
#                                                  242.82789688119792,
#                                                  218.60863604590665,
#                                                  257.24338876355915,
#                                                  224.57629672018425,
#                                                  249.67078700665556,
#                                                  227.7047753879759,
#                                                  247.8561808078602,
#                                                  217.80994736954256,
#                                                  233.38869007254254,
#                                                  243.9830124882198,
#                                                  247.995009687,
#                                                  262.5488967135,
#                                                  235.2243025889,
#                                                  235.37689434153262],
#                      'Average Energy Efficiency per Node [bytes / joule]': [0.1572916123962078,
#                                                                             0.1867518960573829,
#                                                                             0.1468449588018332,
#                                                                             0.15884646864185883,
#                                                                             0.15924378178972895,
#                                                                             0.18852469926792548,
#                                                                             0.18820301388753072,
#                                                                             0.20037293348803328,
#                                                                             0.1490228188626503,
#                                                                             0.19081990467532936,
#                                                                             0.15069866412930744,
#                                                                             0.18467513683380982,
#                                                                             0.16782911804139616,
#                                                                             0.19080894239406299,
#                                                                             0.1927753971115597,
#                                                                             0.19300054998487767,
#                                                                             0.1863174464406117,
#                                                                             0.15131824254345658,
#                                                                             0.1694436542482901,
#                                                                             0.18406177181701544,
#                                                                             0.18836258254541657],
#                      'Data': [4914.0,
#                               5733.0,
#                               4662.0,
#                               4977.0,
#                               4977.0,
#                               5796.0,
#                               5796.0,
#                               6048.0,
#                               4725.0,
#                               5859.0,
#                               4788.0,
#                               5670.0,
#                               5229.0,
#                               5859.0,
#                               5922.0,
#                               5922.0,
#                               5733.0,
#                               4788.0,
#                               5292.0,
#                               5670.0,
#                               5796.0],
#                      'Jain Fairness Index': [0.0156,
#                                              0.017808602150537634,
#                                              0.0148,
#                                              0.015409876543209876,
#                                              0.01503855421686747,
#                                              0.01800851063829787,
#                                              0.0184,
#                                              0.018808163265306124,
#                                              0.01461038961038961,
#                                              0.0186,
#                                              0.0152,
#                                              0.018,
#                                              0.015480898876404494,
#                                              0.01820842105263158,
#                                              0.018408333333333332,
#                                              0.017672,
#                                              0.017808602150537634,
#                                              0.01481025641025641,
#                                              0.0168,
#                                              0.018,
#                                              0.0184],
#                      'Network Energy Efficiency [bytes / joule]': [0.1571632315048734,
#                                                                    0.18659761207048425,
#                                                                    0.14672736185731935,
#                                                                    0.15871709902478118,
#                                                                    0.1591137644592129,
#                                                                    0.18836906597128245,
#                                                                    0.18804791104284502,
#                                                                    0.20020648362226137,
#                                                                    0.14890323465758354,
#                                                                    0.19066205684212498,
#                                                                    0.15057789510845937,
#                                                                    0.18452270163158205,
#                                                                    0.16769125942592214,
#                                                                    0.19065111268902019,
#                                                                    0.1926182856261794,
#                                                                    0.19284307143697815,
#                                                                    0.18616387915962576,
#                                                                    0.15119465586770928,
#                                                                    0.16930470130107167,
#                                                                    0.18391034708994786,
#                                                                    0.18820721668869303],
#                      'Overhead': [873684.0,
#                                   858198.0,
#                                   890101.0,
#                                   876601.0,
#                                   874067.0,
#                                   859643.0,
#                                   861325.0,
#                                   843669.0,
#                                   888744.0,
#                                   858361.0,
#                                   890834.0,
#                                   858371.0,
#                                   870919.0,
#                                   858418.0,
#                                   860998.0,
#                                   859840.0,
#                                   860479.0,
#                                   884448.0,
#                                   873299.0,
#                                   861637.0,
#                                   860498.0],
#                      'Satellite Energy Efficiency [bytes / joule]': [192.5555885759919,
#                                                                      225.86568155539928,
#                                                                      183.22052070408043,
#                                                                      194.8807707920352,
#                                                                      194.8807707920352,
#                                                                      228.1788169986904,
#                                                                      228.1788169986904,
#                                                                      241.00926871087265,
#                                                                      185.5594537258647,
#                                                                      230.48853299563274,
#                                                                      187.8949376330202,
#                                                                      223.5491190665946,
#                                                                      204.14738734994467,
#                                                                      230.48853299563274,
#                                                                      236.3421516424887,
#                                                                      236.3421516424887,
#                                                                      225.86568155539928,
#                                                                      185.1211667400461,
#                                                                      206.4555509194805,
#                                                                      223.5491190665946,
#                                                                      228.1788169986904],
#                      'Throughput [bytes / hour]': [32760.0,
#                                                    38220.0,
#                                                    31080.0,
#                                                    33180.0,
#                                                    33180.0,
#                                                    38640.0,
#                                                    38640.0,
#                                                    40320.0,
#                                                    31500.0,
#                                                    39060.0,
#                                                    31920.0,
#                                                    37800.0,
#                                                    34860.0,
#                                                    39060.0,
#                                                    39480.0,
#                                                    39480.0,
#                                                    38220.0,
#                                                    31920.0,
#                                                    35280.0,
#                                                    37800.0,
#                                                    38640.0]}}}

# %%
output_dir = "output_graphs"

def plot_runs(metric_names, label, ylims, is_log=False, show_metric_name=False):
    for metric in metric_names:
        for key in dfs:
            x = metrics[key].keys()
            ys = [metrics[key][node_count][metric] for node_count in x]
            y = [np.average(y) for y in ys]
            yerr = [np.std(y) for y in ys]

            key_label = key if not show_metric_name else f"{metric} - {key}"
            plt.errorbar(x, y, yerr=yerr, label=key_label, capsize=4, clip_on=False)
    
    plt.ylabel(label)
    plt.xlabel("Number of nodes")
    plt.legend(loc="lower left")
    plt.grid(linestyle='-', color='0.95')
    
    if is_log:
        plt.yscale("log")  
    
    plt.ylim(ylims[0], ylims[1])
    plt.xlim(10, 5000)

    plt.savefig(os.path.join(output_dir, f"{label.replace(' ', '_').replace('/', '_')}.png"))
    plt.show()

##### Satellite Energy Efficiency [bytes / joule]
metric = "Satellite Energy Efficiency [bytes / joule]"
plot_runs([metric], metric, [0, 400], False)

##### Average Energy Efficiency per Node [bytes / joule]
metric = "Average Energy Efficiency per Node [bytes / joule]"
plot_runs([metric], metric, [0.1, 100], True)

##### Network Energy Efficiency [bytes / joule]
metric = "Network Energy Efficiency [bytes / joule]"
plot_runs([metric], metric, [0.1, 100], True)

##### Jain Fairness Index
metric = "Jain Fairness Index"
plot_runs([metric], metric, [0.001, 1], True)

##### Throughput bytes / hour
metric = "Throughput [bytes / hour]"
plot_runs([metric], metric, [10000, 100000])

##### Overhead and data [bytes]
plot_runs(["Overhead", "Data"], "Overhead and data [bytes]", [100, 1000000], True, True)

##### Average Delay [seconds]
metric = "Average Delay [seconds]"
plot_runs([metric], metric, [0, 400])
