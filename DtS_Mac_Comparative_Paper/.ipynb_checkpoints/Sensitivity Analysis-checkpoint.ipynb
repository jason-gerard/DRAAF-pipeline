# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pprint

# opp_run -m -u Cmdenv -c RESS-IoT_Sensitivity_Analysis -n "../../src:..:../../../inet4.3/src:../../../inet4.3/examples:../../../inet4.3/tutorials:../../../inet4.3/showcases" -x "inet.emulation;inet.showcases.visualizer.osg;inet.showcases.emulation;inet.clock.common;inet.clock.model;inet.visualizer.osg;inet.examples.voipstream;inet.clock.oscillator;inet.examples.emulation;inet.transportlayer.tcp_lwip;inet.applications.voipstream;inet.clock.base;inet.examples.clock;inet.transportlayer.tcp_nsc" --image-path=../../images:../../../inet4.3/images -l ../../src/flora -l ../../../inet4.3/src/INET --cmdenv-express-mode=true omnetpp.ini

# %%
def get_throughput_bytes_per_hour(df):
    # Throughput B / hr
    sim_time_hours = float(df.loc[df['name'] == 'simulated time'].value.iloc[0]) / 60 / 60
    bytes_per_data_packet = int(df.loc[df['name'] == 'dataPacketLenBits'].value.iloc[0]) / 8
    num_data_packets = int(df.loc[df['name'] == 'numDataPacketsReceived'].value.iloc[0])

    return (num_data_packets * bytes_per_data_packet) / sim_time_hours

def get_jfi(df):
    # Jain's Fairness Index
    num_nodes = int(df.loc[df['name'] == 'nrOfNodes'].value.iloc[0])
    denominator = num_nodes * df[df['name'].str.startswith('numDataPacketsReceivedByNodeId', na=False)].value.astype(int).pow(2).sum()
    numerator =  df[df['name'].str.startswith('numDataPacketsReceivedByNodeId', na=False)].value.astype(int).sum() ** 2.0
    jfi = numerator / denominator if denominator != 0 else 0
    return jfi

# %%
import os

data_dir = "sensitivity_data"
sca_files = [f for f in os.listdir(data_dir) if ".sca" in f and "RESS-IoT" in f]

sim_data = []

for file_name in sca_files:
    df = pd.read_csv(f"{os.path.join(data_dir, file_name)}", dtype=str)
    
    name = file_name.split('_')[0]
    parts = file_name.split('-')[2].split(",")
    params = [param.split("=")[1] for param in parts]
    run_data = [name, get_throughput_bytes_per_hour(df), get_jfi(df), *params]
    
    sim_data.append(run_data)

sim_data.sort(key=lambda run_data: (int(run_data[-1]), int(run_data[1]), float(run_data[2])))

header = [
    "Protocol",
    "Throughput [bytes / hour]",
    "Jain Fairness Index",
    "wrx",
    "alpha",
    "multiplier",
    "nrOfNodes",
]

sim_data.insert(0, header)    

pd.set_option('display.max_rows', None)
display(pd.DataFrame(sim_data))
df = None
# Out:
#             0                          1                    2    3      4
# 0    Protocol  Throughput [bytes / hour]  Jain Fairness Index  wrx  alpha  \
# 1    RESS-IoT                    31752.0             0.956098    9   0.15
# 2    RESS-IoT                    33453.0             0.885751    9   0.15
# 3    RESS-IoT                    34020.0             0.952381    9  0.125
# 4    RESS-IoT                    34587.0             0.914251    7    0.1
# 5    RESS-IoT                    34587.0             0.932581    7    0.2
# 6    RESS-IoT                    34587.0             0.951662    7  0.175
# 7    RESS-IoT                    35154.0             0.942157    5    0.2
# 8    RESS-IoT                    35721.0               0.9041    9  0.175
# 9    RESS-IoT                    36288.0             0.864135    5  0.125
# 10   RESS-IoT                    36288.0             0.894323    7    0.1
# 11   RESS-IoT                    36288.0             0.910222    9    0.1
# 12   RESS-IoT                    36288.0             0.930909    5    0.1
# 13   RESS-IoT                    37422.0             0.934764    9    0.1
# 14   RESS-IoT                    37989.0             0.864933    5  0.125
# 15   RESS-IoT                    37989.0             0.945053    5    0.2
# 16   RESS-IoT                    38556.0             0.906667    7  0.175
# 17   RESS-IoT                    38556.0              0.95144    7  0.125
# 18   RESS-IoT                    39123.0             0.873578    7    0.2
# 19   RESS-IoT                    39123.0              0.96572    7   0.15
# 20   RESS-IoT                    39690.0             0.968379    9    0.2
# 21   RESS-IoT                    40257.0             0.892212    9  0.175
# 22   RESS-IoT                    40257.0             0.892212    5    0.1
# 23   RESS-IoT                    40824.0             0.893793    7  0.125
# 24   RESS-IoT                    40824.0             0.906294    5   0.15
# 25   RESS-IoT                    40824.0              0.92242    7   0.15
# 26   RESS-IoT                    41958.0             0.866456    5  0.175
# 27   RESS-IoT                    41958.0             0.897705    9  0.125
# 28   RESS-IoT                    43092.0               0.9025    9    0.2
# 29   RESS-IoT                    43659.0              0.94864    5   0.15
# 30   RESS-IoT                    48195.0             0.920382    5  0.175
# 31   RESS-IoT                    34587.0             0.400108    5    0.1
# 32   RESS-IoT                    41391.0              0.45547    7    0.1
# 33   RESS-IoT                    42525.0             0.442913    5    0.1
# 34   RESS-IoT                    44793.0             0.462296    9    0.1
# 35   RESS-IoT                    48762.0             0.474103    7    0.1
# 36   RESS-IoT                    49896.0             0.530411    9    0.1
# 37   RESS-IoT                    51597.0                 0.49    7  0.125
# 38   RESS-IoT                    52164.0              0.50381    9  0.125
# 39   RESS-IoT                    56700.0             0.515464    9  0.125
# 40   RESS-IoT                    56700.0             0.520833    5  0.125
# 41   RESS-IoT                    57834.0             0.536289    7  0.125
# 42   RESS-IoT                    60102.0              0.59766    5  0.125
# 43   RESS-IoT                    61803.0             0.585271    7   0.15
# 44   RESS-IoT                    65772.0             0.585043    5  0.175
# 45   RESS-IoT                    66906.0             0.548189    9   0.15
# 46   RESS-IoT                    66906.0                 0.59    5   0.15
# 47   RESS-IoT                    68607.0             0.650711    7   0.15
# 48   RESS-IoT                    69174.0             0.531571    9   0.15
# 49   RESS-IoT                    69174.0                 0.61    5    0.2
# 50   RESS-IoT                    70308.0              0.61504    5  0.175
# 51   RESS-IoT                    71442.0             0.555105    9    0.2
# 52   RESS-IoT                    72009.0             0.595166    5   0.15
# 53   RESS-IoT                    72576.0             0.549799    9  0.175
# 54   RESS-IoT                    74277.0              0.61509    7  0.175
# 55   RESS-IoT                    74844.0             0.617872    7  0.175
# 56   RESS-IoT                    76545.0             0.574921    9  0.175
# 57   RESS-IoT                    77679.0             0.631953    5    0.2
# 58   RESS-IoT                    78246.0              0.65669    7    0.2
# 59   RESS-IoT                    79947.0             0.589941    7    0.2
# 60   RESS-IoT                    82215.0             0.585655    9    0.2
# 61   RESS-IoT                    11340.0                 0.02    5    0.2
# 62   RESS-IoT                    12474.0                0.022    5    0.2
# 63   RESS-IoT                    21546.0                0.038    7    0.2
# 64   RESS-IoT                    22113.0             0.037098    5  0.175
# 65   RESS-IoT                    23247.0                0.041    7    0.2
# 66   RESS-IoT                    28350.0             0.048077    9    0.2
# 67   RESS-IoT                    31185.0                0.055    5  0.175
# 68   RESS-IoT                    33453.0             0.051955    9    0.2
# 69   RESS-IoT                    36288.0             0.056889    7  0.175
# 70   RESS-IoT                    36855.0             0.061232    7  0.175
# 71   RESS-IoT                    38556.0             0.062486    9  0.175
# 72   RESS-IoT                    44793.0             0.073424    7    0.1
# 73   RESS-IoT                    44793.0             0.075193    5    0.1
# 74   RESS-IoT                    47628.0               0.0784    5    0.1
# 75   RESS-IoT                    48762.0             0.075469    5  0.125
# 76   RESS-IoT                    48762.0             0.077042    9    0.1
# 77   RESS-IoT                    49896.0              0.07902    5   0.15
# 78   RESS-IoT                    49896.0             0.082383    5   0.15
# 79   RESS-IoT                    51030.0                0.081    9  0.175
# 80   RESS-IoT                    51030.0             0.082653    7    0.1
# 81   RESS-IoT                    52164.0             0.081385    9    0.1
# 82   RESS-IoT                    52731.0             0.089165    7   0.15
# 83   RESS-IoT                    53865.0             0.093041    7   0.15
# 84   RESS-IoT                    56133.0             0.091598    9  0.125
# 85   RESS-IoT                    57834.0             0.094582    9  0.125
# 86   RESS-IoT                    58401.0             0.087678    9   0.15
# 87   RESS-IoT                    58968.0             0.094877    5  0.125
# 88   RESS-IoT                    59535.0              0.09587    9   0.15
# 89   RESS-IoT                    60669.0             0.099557    7  0.125
# 90   RESS-IoT                    63504.0             0.101161    7  0.125
# 91   RESS-IoT                     5103.0               0.0045    5    0.2
# 92   RESS-IoT                     5103.0               0.0045    5    0.2
# 93   RESS-IoT                     8505.0               0.0075    7    0.2
# 94   RESS-IoT                     9072.0                0.008    5  0.175
# 95   RESS-IoT                     9639.0               0.0085    7    0.2
# 96   RESS-IoT                    10206.0                0.009    9    0.2
# 97   RESS-IoT                    13608.0                0.012    9    0.2
# 98   RESS-IoT                    14175.0               0.0125    5  0.175
# 99   RESS-IoT                    14742.0                0.013    7  0.175
# 100  RESS-IoT                    15309.0               0.0135    7  0.175
# 101  RESS-IoT                    22680.0                 0.02    9  0.175
# 102  RESS-IoT                    25515.0             0.021543    5   0.15
# 103  RESS-IoT                    26649.0             0.022541    5   0.15
# 104  RESS-IoT                    30618.0             0.026036    9  0.175
# 105  RESS-IoT                    33453.0               0.0295    7   0.15
# 106  RESS-IoT                    38556.0             0.033029    9   0.15
# 107  RESS-IoT                    40824.0                0.036    9   0.15
# 108  RESS-IoT                    42525.0               0.0375    5    0.1
# 109  RESS-IoT                    44226.0             0.038025    7    0.1
# 110  RESS-IoT                    44793.0             0.038525    7   0.15
# 111  RESS-IoT                    44793.0             0.038525    5  0.125
# 112  RESS-IoT                    47628.0               0.0392    5  0.125
# 113  RESS-IoT                    47628.0             0.041023    9    0.1
# 114  RESS-IoT                    50463.0             0.043522    7    0.1
# 115  RESS-IoT                    50463.0             0.043522    5    0.1
# 116  RESS-IoT                    51597.0             0.044522    9    0.1
# 117  RESS-IoT                    52164.0             0.044083    9  0.125
# 118  RESS-IoT                    53298.0             0.045082    7  0.125
# 119  RESS-IoT                    55566.0             0.044463    9  0.125
# 120  RESS-IoT                    56700.0              0.04902    7  0.125
#
#               5          6
# 0    multiplier  nrOfNodes
# 1           0.2         10
# 2           0.1         10
# 3           0.1         10
# 4           0.2         10
# 5           0.2         10
# 6           0.1         10
# 7           0.1         10
# 8           0.1         10
# 9           0.2         10
# 10          0.1         10
# 11          0.2         10
# 12          0.2         10
# 13          0.1         10
# 14          0.1         10
# 15          0.2         10
# 16          0.2         10
# 17          0.2         10
# 18          0.1         10
# 19          0.1         10
# 20          0.2         10
# 21          0.2         10
# 22          0.1         10
# 23          0.1         10
# 24          0.1         10
# 25          0.2         10
# 26          0.1         10
# 27          0.2         10
# 28          0.1         10
# 29          0.2         10
# 30          0.2         10
# 31          0.1        100
# 32          0.2        100
# 33          0.2        100
# 34          0.2        100
# 35          0.1        100
# 36          0.1        100
# 37          0.1        100
# 38          0.1        100
# 39          0.2        100
# 40          0.1        100
# 41          0.2        100
# 42          0.2        100
# 43          0.2        100
# 44          0.1        100
# 45          0.1        100
# 46          0.1        100
# 47          0.1        100
# 48          0.2        100
# 49          0.1        100
# 50          0.2        100
# 51          0.1        100
# 52          0.2        100
# 53          0.2        100
# 54          0.2        100
# 55          0.1        100
# 56          0.1        100
# 57          0.2        100
# 58          0.1        100
# 59          0.2        100
# 60          0.2        100
# 61          0.2       1000
# 62          0.1       1000
# 63          0.1       1000
# 64          0.1       1000
# 65          0.2       1000
# 66          0.1       1000
# 67          0.2       1000
# 68          0.2       1000
# 69          0.2       1000
# 70          0.1       1000
# 71          0.2       1000
# 72          0.1       1000
# 73          0.1       1000
# 74          0.2       1000
# 75          0.1       1000
# 76          0.1       1000
# 77          0.2       1000
# 78          0.1       1000
# 79          0.1       1000
# 80          0.2       1000
# 81          0.2       1000
# 82          0.2       1000
# 83          0.1       1000
# 84          0.1       1000
# 85          0.2       1000
# 86          0.2       1000
# 87          0.2       1000
# 88          0.1       1000
# 89          0.1       1000
# 90          0.2       1000
# 91          0.1       2000
# 92          0.2       2000
# 93          0.1       2000
# 94          0.1       2000
# 95          0.2       2000
# 96          0.1       2000
# 97          0.2       2000
# 98          0.2       2000
# 99          0.1       2000
# 100         0.2       2000
# 101         0.1       2000
# 102         0.1       2000
# 103         0.2       2000
# 104         0.2       2000
# 105         0.2       2000
# 106         0.2       2000
# 107         0.1       2000
# 108         0.1       2000
# 109         0.2       2000
# 110         0.1       2000
# 111         0.2       2000
# 112         0.1       2000
# 113         0.2       2000
# 114         0.1       2000
# 115         0.2       2000
# 116         0.1       2000
# 117         0.2       2000
# 118         0.2       2000
# 119         0.1       2000
# 120         0.1       2000

# %%
metrics = {}

node_counts = set([row[-1] for row in sim_data[1:]])

for row in sim_data[1:]:
    key = f'{row[0]} ({sim_data[0][3]}: {row[3]}, {sim_data[0][4]}: {row[4]}, {sim_data[0][5]}: {row[5]})'
    if key not in metrics:
        metrics[key] = {int(node_count): {} for node_count in node_counts}
    
    metrics[key][int(row[-1])] = {
        "Throughput [bytes / hour]": [row[1]],
        "Jain Fairness Index": [row[2]],
    }

pprint.pprint(metrics)
# Out:
# {'RESS-IoT (wrx: 5, alpha: 0.1, multiplier: 0.1)': {10: {'Jain Fairness Index': [0.8922123893805309],
#                                                          'Throughput [bytes / hour]': [40257.0]},
#                                                     100: {'Jain Fairness Index': [0.4001075268817204],
#                                                           'Throughput [bytes / hour]': [34587.0]},
#                                                     1000: {'Jain Fairness Index': [0.07519277108433735],
#                                                            'Throughput [bytes / hour]': [44793.0]},
#                                                     2000: {'Jain Fairness Index': [0.0375],
#                                                            'Throughput [bytes / hour]': [42525.0]}},
#  'RESS-IoT (wrx: 5, alpha: 0.1, multiplier: 0.2)': {10: {'Jain Fairness Index': [0.9309090909090909],
#                                                          'Throughput [bytes / hour]': [36288.0]},
#                                                     100: {'Jain Fairness Index': [0.44291338582677164],
#                                                           'Throughput [bytes / hour]': [42525.0]},
#                                                     1000: {'Jain Fairness Index': [0.0784],
#                                                            'Throughput [bytes / hour]': [47628.0]},
#                                                     2000: {'Jain Fairness Index': [0.04352197802197802],
#                                                            'Throughput [bytes / hour]': [50463.0]}},
#  'RESS-IoT (wrx: 5, alpha: 0.125, multiplier: 0.1)': {10: {'Jain Fairness Index': [0.8649325626204238],
#                                                            'Throughput [bytes / hour]': [37989.0]},
#                                                       100: {'Jain Fairness Index': [0.5208333333333334],
#                                                             'Throughput [bytes / hour]': [56699.99999999999]},
#                                                       1000: {'Jain Fairness Index': [0.07546938775510204],
#                                                              'Throughput [bytes / hour]': [48762.0]},
#                                                       2000: {'Jain Fairness Index': [0.0392],
#                                                              'Throughput [bytes / hour]': [47628.0]}},
#  'RESS-IoT (wrx: 5, alpha: 0.125, multiplier: 0.2)': {10: {'Jain Fairness Index': [0.8641350210970464],
#                                                            'Throughput [bytes / hour]': [36288.0]},
#                                                       100: {'Jain Fairness Index': [0.5976595744680852],
#                                                             'Throughput [bytes / hour]': [60101.99999999999]},
#                                                       1000: {'Jain Fairness Index': [0.09487719298245614],
#                                                              'Throughput [bytes / hour]': [58967.99999999999]},
#                                                       2000: {'Jain Fairness Index': [0.03852469135802469],
#                                                              'Throughput [bytes / hour]': [44793.0]}},
#  'RESS-IoT (wrx: 5, alpha: 0.15, multiplier: 0.1)': {10: {'Jain Fairness Index': [0.9062937062937063],
#                                                           'Throughput [bytes / hour]': [40824.0]},
#                                                      100: {'Jain Fairness Index': [0.59],
#                                                            'Throughput [bytes / hour]': [66906.0]},
#                                                      1000: {'Jain Fairness Index': [0.08238297872340425],
#                                                             'Throughput [bytes / hour]': [49896.0]},
#                                                      2000: {'Jain Fairness Index': [0.02154255319148936],
#                                                             'Throughput [bytes / hour]': [25515.0]}},
#  'RESS-IoT (wrx: 5, alpha: 0.15, multiplier: 0.2)': {10: {'Jain Fairness Index': [0.94864],
#                                                           'Throughput [bytes / hour]': [43659.0]},
#                                                      100: {'Jain Fairness Index': [0.5951660516605166],
#                                                            'Throughput [bytes / hour]': [72009.0]},
#                                                      1000: {'Jain Fairness Index': [0.0790204081632653],
#                                                             'Throughput [bytes / hour]': [49896.0]},
#                                                      2000: {'Jain Fairness Index': [0.022540816326530613],
#                                                             'Throughput [bytes / hour]': [26648.999999999996]}},
#  'RESS-IoT (wrx: 5, alpha: 0.175, multiplier: 0.1)': {10: {'Jain Fairness Index': [0.8664556962025316],
#                                                            'Throughput [bytes / hour]': [41958.0]},
#                                                       100: {'Jain Fairness Index': [0.5850434782608696],
#                                                             'Throughput [bytes / hour]': [65772.0]},
#                                                       1000: {'Jain Fairness Index': [0.037097560975609754],
#                                                              'Throughput [bytes / hour]': [22113.0]},
#                                                       2000: {'Jain Fairness Index': [0.008],
#                                                              'Throughput [bytes / hour]': [9072.0]}},
#  'RESS-IoT (wrx: 5, alpha: 0.175, multiplier: 0.2)': {10: {'Jain Fairness Index': [0.9203821656050956],
#                                                            'Throughput [bytes / hour]': [48195.0]},
#                                                       100: {'Jain Fairness Index': [0.61504],
#                                                             'Throughput [bytes / hour]': [70308.0]},
#                                                       1000: {'Jain Fairness Index': [0.055],
#                                                              'Throughput [bytes / hour]': [31184.999999999996]},
#                                                       2000: {'Jain Fairness Index': [0.0125],
#                                                              'Throughput [bytes / hour]': [14174.999999999998]}},
#  'RESS-IoT (wrx: 5, alpha: 0.2, multiplier: 0.1)': {10: {'Jain Fairness Index': [0.942156862745098],
#                                                          'Throughput [bytes / hour]': [35154.0]},
#                                                     100: {'Jain Fairness Index': [0.61],
#                                                           'Throughput [bytes / hour]': [69174.0]},
#                                                     1000: {'Jain Fairness Index': [0.022],
#                                                            'Throughput [bytes / hour]': [12474.0]},
#                                                     2000: {'Jain Fairness Index': [0.0045],
#                                                            'Throughput [bytes / hour]': [5103.0]}},
#  'RESS-IoT (wrx: 5, alpha: 0.2, multiplier: 0.2)': {10: {'Jain Fairness Index': [0.9450526315789474],
#                                                          'Throughput [bytes / hour]': [37989.0]},
#                                                     100: {'Jain Fairness Index': [0.6319528619528619],
#                                                           'Throughput [bytes / hour]': [77679.0]},
#                                                     1000: {'Jain Fairness Index': [0.02],
#                                                            'Throughput [bytes / hour]': [11340.0]},
#                                                     2000: {'Jain Fairness Index': [0.0045],
#                                                            'Throughput [bytes / hour]': [5103.0]}},
#  'RESS-IoT (wrx: 7, alpha: 0.1, multiplier: 0.1)': {10: {'Jain Fairness Index': [0.8943231441048035],
#                                                          'Throughput [bytes / hour]': [36288.0]},
#                                                     100: {'Jain Fairness Index': [0.47410256410256413],
#                                                           'Throughput [bytes / hour]': [48762.0]},
#                                                     1000: {'Jain Fairness Index': [0.0734235294117647],
#                                                            'Throughput [bytes / hour]': [44793.0]},
#                                                     2000: {'Jain Fairness Index': [0.04352197802197802],
#                                                            'Throughput [bytes / hour]': [50463.0]}},
#  'RESS-IoT (wrx: 7, alpha: 0.1, multiplier: 0.2)': {10: {'Jain Fairness Index': [0.9142506142506143],
#                                                          'Throughput [bytes / hour]': [34587.0]},
#                                                     100: {'Jain Fairness Index': [0.4554700854700855],
#                                                           'Throughput [bytes / hour]': [41391.0]},
#                                                     1000: {'Jain Fairness Index': [0.0826530612244898],
#                                                            'Throughput [bytes / hour]': [51030.0]},
#                                                     2000: {'Jain Fairness Index': [0.038025],
#                                                            'Throughput [bytes / hour]': [44226.0]}},
#  'RESS-IoT (wrx: 7, alpha: 0.125, multiplier: 0.1)': {10: {'Jain Fairness Index': [0.8937931034482759],
#                                                            'Throughput [bytes / hour]': [40824.0]},
#                                                       100: {'Jain Fairness Index': [0.49],
#                                                             'Throughput [bytes / hour]': [51597.0]},
#                                                       1000: {'Jain Fairness Index': [0.09955652173913043],
#                                                              'Throughput [bytes / hour]': [60668.99999999999]},
#                                                       2000: {'Jain Fairness Index': [0.049019607843137254],
#                                                              'Throughput [bytes / hour]': [56699.99999999999]}},
#  'RESS-IoT (wrx: 7, alpha: 0.125, multiplier: 0.2)': {10: {'Jain Fairness Index': [0.951440329218107],
#                                                            'Throughput [bytes / hour]': [38556.0]},
#                                                       100: {'Jain Fairness Index': [0.5362886597938145],
#                                                             'Throughput [bytes / hour]': [57833.99999999999]},
#                                                       1000: {'Jain Fairness Index': [0.10116129032258064],
#                                                              'Throughput [bytes / hour]': [63503.99999999999]},
#                                                       2000: {'Jain Fairness Index': [0.04508163265306123],
#                                                              'Throughput [bytes / hour]': [53297.99999999999]}},
#  'RESS-IoT (wrx: 7, alpha: 0.15, multiplier: 0.1)': {10: {'Jain Fairness Index': [0.9657200811359027],
#                                                           'Throughput [bytes / hour]': [39123.0]},
#                                                      100: {'Jain Fairness Index': [0.6507111111111111],
#                                                            'Throughput [bytes / hour]': [68607.0]},
#                                                      1000: {'Jain Fairness Index': [0.09304123711340206],
#                                                             'Throughput [bytes / hour]': [53864.99999999999]},
#                                                      2000: {'Jain Fairness Index': [0.03852469135802469],
#                                                             'Throughput [bytes / hour]': [44793.0]}},
#  'RESS-IoT (wrx: 7, alpha: 0.15, multiplier: 0.2)': {10: {'Jain Fairness Index': [0.9224199288256227],
#                                                           'Throughput [bytes / hour]': [40824.0]},
#                                                      100: {'Jain Fairness Index': [0.5852709359605911],
#                                                            'Throughput [bytes / hour]': [61802.99999999999]},
#                                                      1000: {'Jain Fairness Index': [0.08916494845360824],
#                                                             'Throughput [bytes / hour]': [52730.99999999999]},
#                                                      2000: {'Jain Fairness Index': [0.0295],
#                                                             'Throughput [bytes / hour]': [33453.0]}},
#  'RESS-IoT (wrx: 7, alpha: 0.175, multiplier: 0.1)': {10: {'Jain Fairness Index': [0.9516624040920716],
#                                                            'Throughput [bytes / hour]': [34587.0]},
#                                                       100: {'Jain Fairness Index': [0.617872340425532],
#                                                             'Throughput [bytes / hour]': [74844.0]},
#                                                       1000: {'Jain Fairness Index': [0.06123188405797102],
#                                                              'Throughput [bytes / hour]': [36855.0]},
#                                                       2000: {'Jain Fairness Index': [0.013],
#                                                              'Throughput [bytes / hour]': [14741.999999999998]}},
#  'RESS-IoT (wrx: 7, alpha: 0.175, multiplier: 0.2)': {10: {'Jain Fairness Index': [0.9066666666666666],
#                                                            'Throughput [bytes / hour]': [38556.0]},
#                                                       100: {'Jain Fairness Index': [0.615089605734767],
#                                                             'Throughput [bytes / hour]': [74277.0]},
#                                                       1000: {'Jain Fairness Index': [0.05688888888888889],
#                                                              'Throughput [bytes / hour]': [36288.0]},
#                                                       2000: {'Jain Fairness Index': [0.0135],
#                                                              'Throughput [bytes / hour]': [15308.999999999998]}},
#  'RESS-IoT (wrx: 7, alpha: 0.2, multiplier: 0.1)': {10: {'Jain Fairness Index': [0.8735779816513761],
#                                                          'Throughput [bytes / hour]': [39123.0]},
#                                                     100: {'Jain Fairness Index': [0.6566896551724138],
#                                                           'Throughput [bytes / hour]': [78246.0]},
#                                                     1000: {'Jain Fairness Index': [0.038],
#                                                            'Throughput [bytes / hour]': [21546.0]},
#                                                     2000: {'Jain Fairness Index': [0.0075],
#                                                            'Throughput [bytes / hour]': [8505.0]}},
#  'RESS-IoT (wrx: 7, alpha: 0.2, multiplier: 0.2)': {10: {'Jain Fairness Index': [0.9325814536340852],
#                                                          'Throughput [bytes / hour]': [34587.0]},
#                                                     100: {'Jain Fairness Index': [0.5899406528189911],
#                                                           'Throughput [bytes / hour]': [79947.0]},
#                                                     1000: {'Jain Fairness Index': [0.041],
#                                                            'Throughput [bytes / hour]': [23247.0]},
#                                                     2000: {'Jain Fairness Index': [0.0085],
#                                                            'Throughput [bytes / hour]': [9639.0]}},
#  'RESS-IoT (wrx: 9, alpha: 0.1, multiplier: 0.1)': {10: {'Jain Fairness Index': [0.934763948497854],
#                                                          'Throughput [bytes / hour]': [37422.0]},
#                                                     100: {'Jain Fairness Index': [0.5304109589041096],
#                                                           'Throughput [bytes / hour]': [49896.0]},
#                                                     1000: {'Jain Fairness Index': [0.07704166666666666],
#                                                            'Throughput [bytes / hour]': [48762.0]},
#                                                     2000: {'Jain Fairness Index': [0.044521505376344084],
#                                                            'Throughput [bytes / hour]': [51597.0]}},
#  'RESS-IoT (wrx: 9, alpha: 0.1, multiplier: 0.2)': {10: {'Jain Fairness Index': [0.9102222222222223],
#                                                          'Throughput [bytes / hour]': [36288.0]},
#                                                     100: {'Jain Fairness Index': [0.4622962962962963],
#                                                           'Throughput [bytes / hour]': [44793.0]},
#                                                     1000: {'Jain Fairness Index': [0.08138461538461539],
#                                                            'Throughput [bytes / hour]': [52164.0]},
#                                                     2000: {'Jain Fairness Index': [0.04102325581395349],
#                                                            'Throughput [bytes / hour]': [47628.0]}},
#  'RESS-IoT (wrx: 9, alpha: 0.125, multiplier: 0.1)': {10: {'Jain Fairness Index': [0.9523809523809523],
#                                                            'Throughput [bytes / hour]': [34020.0]},
#                                                       100: {'Jain Fairness Index': [0.5038095238095238],
#                                                             'Throughput [bytes / hour]': [52164.0]},
#                                                       1000: {'Jain Fairness Index': [0.09159813084112149],
#                                                              'Throughput [bytes / hour]': [56132.99999999999]},
#                                                       2000: {'Jain Fairness Index': [0.04446296296296296],
#                                                              'Throughput [bytes / hour]': [55565.99999999999]}},
#  'RESS-IoT (wrx: 9, alpha: 0.125, multiplier: 0.2)': {10: {'Jain Fairness Index': [0.8977049180327868],
#                                                            'Throughput [bytes / hour]': [41958.0]},
#                                                       100: {'Jain Fairness Index': [0.5154639175257731],
#                                                             'Throughput [bytes / hour]': [56699.99999999999]},
#                                                       1000: {'Jain Fairness Index': [0.09458181818181818],
#                                                              'Throughput [bytes / hour]': [57833.99999999999]},
#                                                       2000: {'Jain Fairness Index': [0.044083333333333335],
#                                                              'Throughput [bytes / hour]': [52164.0]}},
#  'RESS-IoT (wrx: 9, alpha: 0.15, multiplier: 0.1)': {10: {'Jain Fairness Index': [0.8857506361323155],
#                                                           'Throughput [bytes / hour]': [33453.0]},
#                                                      100: {'Jain Fairness Index': [0.5481889763779527],
#                                                            'Throughput [bytes / hour]': [66906.0]},
#                                                      1000: {'Jain Fairness Index': [0.0958695652173913],
#                                                             'Throughput [bytes / hour]': [59534.99999999999]},
#                                                      2000: {'Jain Fairness Index': [0.036],
#                                                             'Throughput [bytes / hour]': [40824.0]}},
#  'RESS-IoT (wrx: 9, alpha: 0.15, multiplier: 0.2)': {10: {'Jain Fairness Index': [0.9560975609756097],
#                                                           'Throughput [bytes / hour]': [31751.999999999996]},
#                                                      100: {'Jain Fairness Index': [0.5315714285714286],
#                                                            'Throughput [bytes / hour]': [69174.0]},
#                                                      1000: {'Jain Fairness Index': [0.08767768595041323],
#                                                             'Throughput [bytes / hour]': [58400.99999999999]},
#                                                      2000: {'Jain Fairness Index': [0.03302857142857143],
#                                                             'Throughput [bytes / hour]': [38556.0]}},
#  'RESS-IoT (wrx: 9, alpha: 0.175, multiplier: 0.1)': {10: {'Jain Fairness Index': [0.9041002277904328],
#                                                            'Throughput [bytes / hour]': [35721.0]},
#                                                       100: {'Jain Fairness Index': [0.5749211356466877],
#                                                             'Throughput [bytes / hour]': [76545.0]},
#                                                       1000: {'Jain Fairness Index': [0.081],
#                                                              'Throughput [bytes / hour]': [51030.0]},
#                                                       2000: {'Jain Fairness Index': [0.02],
#                                                              'Throughput [bytes / hour]': [22680.0]}},
#  'RESS-IoT (wrx: 9, alpha: 0.175, multiplier: 0.2)': {10: {'Jain Fairness Index': [0.8922123893805309],
#                                                            'Throughput [bytes / hour]': [40257.0]},
#                                                       100: {'Jain Fairness Index': [0.5497986577181208],
#                                                             'Throughput [bytes / hour]': [72576.0]},
#                                                       1000: {'Jain Fairness Index': [0.062486486486486484],
#                                                              'Throughput [bytes / hour]': [38556.0]},
#                                                       2000: {'Jain Fairness Index': [0.026035714285714287],
#                                                              'Throughput [bytes / hour]': [30617.999999999996]}},
#  'RESS-IoT (wrx: 9, alpha: 0.2, multiplier: 0.1)': {10: {'Jain Fairness Index': [0.9025],
#                                                          'Throughput [bytes / hour]': [43092.0]},
#                                                     100: {'Jain Fairness Index': [0.5551048951048951],
#                                                           'Throughput [bytes / hour]': [71442.0]},
#                                                     1000: {'Jain Fairness Index': [0.04807692307692308],
#                                                            'Throughput [bytes / hour]': [28349.999999999996]},
#                                                     2000: {'Jain Fairness Index': [0.009],
#                                                            'Throughput [bytes / hour]': [10206.0]}},
#  'RESS-IoT (wrx: 9, alpha: 0.2, multiplier: 0.2)': {10: {'Jain Fairness Index': [0.9683794466403162],
#                                                          'Throughput [bytes / hour]': [39690.0]},
#                                                     100: {'Jain Fairness Index': [0.5856545961002786],
#                                                           'Throughput [bytes / hour]': [82215.0]},
#                                                     1000: {'Jain Fairness Index': [0.051955223880597014],
#                                                            'Throughput [bytes / hour]': [33453.0]},
#                                                     2000: {'Jain Fairness Index': [0.012],
#                                                            'Throughput [bytes / hour]': [13607.999999999998]}}}

# %%
output_dir = "output_graphs"

def plot_runs(metric_names, label, ylims, is_log=False, show_metric_name=False):
    for metric in metric_names:
        for index, key in enumerate(metrics):
            x = metrics[key].keys()
            ys = [metrics[key][node_count][metric] for node_count in x]
            y = [np.average(y) for y in ys]

            key_label = key if not show_metric_name else f"{metric} - {key}"
            
            if key_label == "RESS-IoT (wrx: 7, alpha: 0.125, multiplier: 0.1)":
                color = "#990000"
                zorder = 999
            else:
                color = "#999999"
                zorder = 2
                if index == len(metrics) - 1:
                    key_label = "Other"
                else:
                    key_label = "_nolegend_"
            plt.plot(x, y, label=key_label, color=color, zorder=zorder, clip_on=False)
    
    plt.ylabel(label)
    plt.xlabel("Number of nodes")
    plt.legend(loc="lower left")
    plt.grid(linestyle='-', color='0.95')
    
    if is_log:
        plt.yscale("log")  
    
    plt.ylim(ylims[0], ylims[1])
    plt.xlim(10, 2000)

    plt.savefig(os.path.join(output_dir, f"sensitivity_RESS-IoT_{label.replace(' ', '_').replace('/', '_')}.png"))
    plt.show()
    
##### Jain Fairness Index
metric = "Jain Fairness Index"
plot_runs([metric], metric, [0.001, 1], True)

##### Throughput bytes / hour
metric = "Throughput [bytes / hour]"
plot_runs([metric], metric, [0, 100000])

# %%
### DQ Below

# %%
import os

data_dir = "sensitivity_data"
sca_files = [f for f in os.listdir(data_dir) if ".sca" in f and "DQ" in f]

sim_data = []

for file_name in sca_files:
    df = pd.read_csv(f"{os.path.join(data_dir, file_name)}", dtype=str)
    
    name = file_name.split('_')[0]
    parts = file_name.split('-')[1].split(",")
    params = [param.split("=")[1] for param in parts]
    run_data = [name, get_throughput_bytes_per_hour(df), get_jfi(df), *params]
    
    sim_data.append(run_data)

sim_data.sort(key=lambda run_data: (int(run_data[-1]), int(run_data[1]), float(run_data[2])))

header = [
    "Protocol",
    "Throughput [bytes / hour]",
    "Jain Fairness Index",
    "numContentionSlots",
    "nrOfNodes",
]

sim_data.insert(0, header)    

pd.set_option('display.max_rows', None)
display(pd.DataFrame(sim_data))
df = None
# Out:
#           0                          1                    2
# 0  Protocol  Throughput [bytes / hour]  Jain Fairness Index  \
# 1        DQ                    39690.0             0.890909
# 2        DQ                    41958.0             0.866456
# 3        DQ                    83916.0             0.693165
# 4        DQ                    88452.0             0.617665
# 5        DQ                    57834.0             0.063439
# 6        DQ                    71442.0             0.095639
# 7        DQ                    37422.0             0.029432
# 8        DQ                    43092.0             0.032089
#
#                     3          4
# 0  numContentionSlots  nrOfNodes
# 1                   5         10
# 2                   3         10
# 3                   5        100
# 4                   3        100
# 5                   3       1000
# 6                   5       1000
# 7                   3       2000
# 8                   5       2000

# %%
metrics = {}

node_counts = set([row[-1] for row in sim_data[1:]])

for row in sim_data[1:]:
    key = f'{row[0]} ({sim_data[0][3]}: {row[3]})'
    if key not in metrics:
        metrics[key] = {int(node_count): {} for node_count in node_counts}
    
    metrics[key][int(row[-1])] = {
        "Throughput [bytes / hour]": [row[1]],
        "Jain Fairness Index": [row[2]],
    }

pprint.pprint(metrics)
# Out:
# {'DQ (numContentionSlots: 3)': {10: {'Jain Fairness Index': [0.8664556962025316],
#                                      'Throughput [bytes / hour]': [41958.0]},
#                                 100: {'Jain Fairness Index': [0.6176649746192894],
#                                       'Throughput [bytes / hour]': [88452.0]},
#                                 1000: {'Jain Fairness Index': [0.0634390243902439],
#                                        'Throughput [bytes / hour]': [57833.99999999999]},
#                                 2000: {'Jain Fairness Index': [0.02943243243243243],
#                                        'Throughput [bytes / hour]': [37422.0]}},
#  'DQ (numContentionSlots: 5)': {10: {'Jain Fairness Index': [0.8909090909090909],
#                                      'Throughput [bytes / hour]': [39690.0]},
#                                 100: {'Jain Fairness Index': [0.6931645569620253],
#                                       'Throughput [bytes / hour]': [83916.0]},
#                                 1000: {'Jain Fairness Index': [0.09563855421686747],
#                                        'Throughput [bytes / hour]': [71442.0]},
#                                 2000: {'Jain Fairness Index': [0.03208888888888889],
#                                        'Throughput [bytes / hour]': [43092.0]}}}

# %%
output_dir = "output_graphs"

def plot_runs(metric_names, label, ylims, is_log=False, show_metric_name=False):
    for metric in metric_names:
        for key in metrics:
            x = metrics[key].keys()
            ys = [metrics[key][node_count][metric] for node_count in x]
            y = [np.average(y) for y in ys]

            key_label = key if not show_metric_name else f"{metric} - {key}"
            
            if key_label == "DQ (numContentionSlots: 5)":
                color = "#990000"
                zorder = 999
            else:
                color = "#999999"
                zorder = 10
                key_label = "Other"
            plt.plot(x, y, label=key_label, color=color, zorder=zorder, clip_on=False)
    
    plt.ylabel(label)
    plt.xlabel("Number of nodes")
    plt.legend(loc="lower left")
    plt.grid(linestyle='-', color='0.95')
    
    if is_log:
        plt.yscale("log")  
    
    plt.ylim(ylims[0], ylims[1])
    plt.xlim(10, 2000)

    plt.savefig(os.path.join(output_dir, f"sensitivity_DQ_{label.replace(' ', '_').replace('/', '_')}.png"))
    plt.show()
    
##### Jain Fairness Index
metric = "Jain Fairness Index"
plot_runs([metric], metric, [0.001, 1], True)

##### Throughput bytes / hour
metric = "Throughput [bytes / hour]"
plot_runs([metric], metric, [0, 100000])
